# %% [markdown]
# ### Testing mulitple simple GNNs

# %% [markdown]
# #### Installations

# %%
# %pip install -r ../../requirements.txt

# %%
# %pip install class_resolver
# Out:
# Collecting class_resolver
#   Downloading class_resolver-0.3.10-py3-none-any.whl (21 kB)
# Installing collected packages: class_resolver
# Successfully installed class_resolver-0.3.10
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# %pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Imports

# %%
# general
import pathlib
import os
import sys
from collections import defaultdict
from tabulate import tabulate
import matplotlib.pyplot as plt
# for py2neo and utils
from py2neo import Graph, Relationship
parent_path = pathlib.Path(os.getcwd()).parent.absolute()
sys.path.append(str(parent_path))

# for PyG
import torch
from torch_geometric.data import HeteroData
from torch_geometric.transforms import RandomLinkSplit, ToUndirected
from torch_geometric.nn import to_hetero, to_hetero_with_bases
import torch.nn.functional as F
from utils_draft.pyg import load_node, load_edge, SequenceEncoder, IdentityEncoder, ListEncoder
from torch.nn import Linear, LazyLinear
from torch_geometric.nn import SAGEConv, GATv2Conv, GCNConv, TransformerConv, GraphConv
from torch_geometric.nn.models import GCN, GraphSAGE, GIN, GAT, PNA, GAE, VGAE

# %% [markdown]
# #### Connecting to the existing neo4j instance

# %%
graph = Graph(
    "bolt://localhost:7687",
    auth=("neo4j", "admin"),
)

# %% [markdown]
# #### Observing the pre-stored graph

# %%
movies_num = graph.nodes.match("Movie").count()
users_num = graph.nodes.match("User").count()
RATES = Relationship.type("RATES")
ratings_num = graph.relationships.match(r_type=RATES).count()
table = [
    ["Movies", movies_num],
    ["Users", users_num],
    ["Ratings", ratings_num]
]
print(tabulate(table, headers=["Type", "Count"], tablefmt="github"))
# Out:
# | Type    |   Count |
# |---------|---------|
# | Movies  |    9460 |
# | Users   |     610 |
# | Ratings |   96150 |

# %% [markdown]
# #### Building the PyG graph

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

movies_x, movies_mapping = load_node(
    graph=graph,
    query="""
        MATCH (m: Movie)
        return m.movieId as movieId, m.title as title, m.genres as genres, m.year as year
    """,
    index_col="movieId",
    encoders={
        "title": SequenceEncoder(),
        "genres": ListEncoder(sep="|"),
        "year": SequenceEncoder(),
    }
)

users_x, users_mapping = load_node(
    graph=graph,
    query="""
        MATCH (u:User)-[r:RATES]-(m:Movie)
        return u.userId as userId, u.username as username, avg(r.rating) as avg_rating, count(r) as ratings;
    """,
    index_col="userId",
    encoders={
        # "avg_rating": IdentityEncoder(dtype=torch.float16),
        # "ratings": IdentityEncoder(dtype=torch.int64),
        "username": SequenceEncoder(),
    }
)

edge_index, edge_label = load_edge(
    graph=graph,
    query="""
        MATCH (u:User)-[r:RATES]-(m:Movie)
        return u.userId as userId, r.rating as rating, r.datetime as datetime, m.movieId as movieId;
    """,
    src_index_col="userId",
    src_mapping=users_mapping,
    dst_index_col="movieId",
    dst_mapping=movies_mapping,
    encoders={
        "rating": IdentityEncoder(dtype=torch.long),
        # "datetime": IdentityEncoder(dtype=torch.long),
    }
)
# Out:
# items: dict_items([('title', <utils.pyg.SequenceEncoder object at 0x0000021CF5F8B3A0>), ('genres', <utils.pyg.ListEncoder object at 0x0000021CCC246BC0>), ('year', <utils.pyg.SequenceEncoder object at 0x0000021CF5F8B340>)])
# Batches:   0%|          | 0/296 [00:00<?, ?it/s]
# Batches:   0%|          | 0/296 [00:00<?, ?it/s]
# items: dict_items([('username', <utils.pyg.SequenceEncoder object at 0x0000021CF5FBC5E0>)])
# Batches:   0%|          | 0/20 [00:00<?, ?it/s]

# %%
movies_x.shape
# Out:
# torch.Size([9460, 788])

# %%
users_x.shape
# Out:
# torch.Size([610, 384])

# %% [markdown]
# #### Building the dataset

# %%
data = HeteroData()
data["user"].x = users_x
data["movie"].x = movies_x
data["user", "reviews", "movie"].edge_index = edge_index
data["user", "reviews", "movie"].edge_label = edge_label
data.to(device, non_blocking=True)
data = ToUndirected()(data)
del data["movie", "rev_reviews", "user"].edge_label

transform = RandomLinkSplit(
    num_val=0.1,
    num_test=0.1,
    neg_sampling_ratio=0.0,
    edge_types=[("user", "reviews", "movie")],
    rev_edge_types=[("movie", "rev_reviews", "user")],
)
train_data, val_data, test_data = transform(data)

# %%
print("train data shape:", train_data.collect('x').get("user").shape)
# Out:
# train data shape: torch.Size([610, 384])

# %% [markdown]
# #### Building the model

# %%
layers = {
    "SAGE": SAGEConv,
    "GAT": GATv2Conv,
    "GCN": GCNConv,
    "Transformer": TransformerConv,
    "GraphConv": GraphConv,
}
encoders = {
    "GNC": GCN,
    "GraphSAGE": GraphSAGE,
    "GIN": GIN,
    "GAT": GAT,
    "PNA": PNA,
}

# %%
class EdgeDecoder(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.lin1 = LazyLinear(hidden_channels)
        self.lin2 = Linear(hidden_channels, hidden_channels)
        self.lin3 = Linear(hidden_channels, hidden_channels)
        self.lin4 = Linear(hidden_channels, 1)

    def forward(self, z_dict, edge_label_index):
        row, col = edge_label_index
        z = torch.cat([z_dict['user'][row], z_dict['movie'][col]], dim=-1)

        z = self.lin1(z).relu()
        z = self.lin2(z).relu()
        z = self.lin3(z).relu()
        z = self.lin4(z)
        return z.view(-1)

# %%
class Model(torch.nn.Module):
    def __init__(self, encoder_name="GCN", in_channels=-1, hidden_channels=32, out_channels=32, num_layers=4, dropout=0):
        super().__init__()
        encoder = encoders.get(encoder_name)
        if not encoder:
            raise Exception(f"Invaid encoder name: {encoder_name}")
        print("INITIALIZING MODEL-ENCODER")
        self.encoder = GraphSAGE(
            in_channels=in_channels,
            hidden_channels=hidden_channels,
            out_channels=out_channels,
            num_layers=num_layers,
            dropout=dropout,
        )
        print("INITIALIZED MODEL-ENCODER")
        self.in_channels = in_channels
        self.hidden_channels = hidden_channels
        self.out_channels = out_channels
        print("TO HETERO-ING MODEL-ENCODER")
        # self.encoder = to_hetero(self.encoder, data.metadata(), aggr='sum')
        # self.encoder = to_hetero_with_bases(self.encoder, data.metadata(), num_bases=3)
        print("TO HETERO MODEL-ENCODER")
        self.decoder = EdgeDecoder(hidden_channels)

    def forward(self, x_dict, edge_index_dict, edge_label_index):
        z_dict = self.encoder(x_dict, edge_index_dict)
        return self.decoder(z_dict, edge_label_index)

# %% [markdown]
# #### Default Loss function

# %% [markdown]
# #### Training

# %%
weight = torch.bincount(train_data['user', 'movie'].edge_label)
weight = weight.max() / weight

def weighted_mse_loss(pred, target, weight=None):
    weight = 1. if weight is None else weight[target].to(pred.dtype)
    return (weight * (pred - target.to(pred.dtype)).pow(2)).mean()

# %%
class ModelBuilderTrainerTester():
    def __init__(self, train_data, val_data, test_data, in_channels=-1, hidden_channels=32, out_channels=32, num_layers=4, encoder_name="GraphSAGE"):
        model = Model(
            in_channels=in_channels,
            hidden_channels=hidden_channels,
            out_channels=out_channels,
            encoder_name=encoder_name,
            num_layers=num_layers,
        ).to(device)
        self.model = model
        self.optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
        self.hidden_channels = hidden_channels
        self.out_channels = out_channels
        self.encoder_name = encoder_name
        self.train_data = train_data
        self.val_data = val_data
        self.test_data = test_data
        self.losses = []
        weight = torch.bincount(train_data['user', 'movie'].edge_label)
        self.weight = weight.max() / weight


    def train(self):
        self.model.train()
        self.optimizer.zero_grad()
        pred = self.model(
            self.train_data.collect('x'),
            self.train_data.edge_index_dict,
            self.train_data['user', 'movie'].edge_label_index
        )
        target = self.train_data['user', 'movie'].edge_label
        loss = weighted_mse_loss(pred, target, weight)
        loss.backward()
        self.optimizer.step()
        return float(loss)

    @torch.no_grad()
    def test(self, data):
        self.model.eval()
        pred = self.model(
            data.collect('x'),
            data.edge_index_dict,
            data['user', 'movie'].edge_label_index,
        )
        pred = pred.clamp(min=0, max=5)
        target = data['user', 'movie'].edge_label.float()
        rmse = F.mse_loss(pred, target).sqrt()
        # print("Predictions:", pred)
        # print("Target:", target)
        return float(rmse)
       
    def train_test(self, epochs):
        # Due to lazy initialization, we need to run one model step so the number
        # of parameters can be inferred:
        with torch.no_grad():
            self.model.encoder(self.train_data.collect('x'), self.train_data.edge_index_dict)
        print("Epoch:", end=" ")
        for epoch in range(1, epochs):
            loss = self.train()
            train_rmse = self.test(self.train_data)
            val_rmse = self.test(self.val_data)
            test_rmse = self.test(self.test_data)
            self.losses.append({
                "loss": loss,
                "train": train_rmse,
                "val": val_rmse,
                "test": test_rmse,
            })
            print (epoch, end=" ")
        total = [loss["loss"] for loss in self.losses]
        train = [loss["train"] for loss in self.losses]
        val = [loss["val"] for loss in self.losses]
        test =  [loss["test"] for loss in self.losses]
        return total, train, val, test

# %% [markdown]
# #### Some tests

# %%
models = [
    {
        "encoder_name": "GraphSAGE",
        "hidden_channels": [32, 64, 128],
        "in_channels": (-1, -1),
        "num_layers": [4, 6, 8],
    },
    # {
    #     "layer_name": "GAT",
    #     "hidden_channels": [32, 64, 128],
    #     "in_channels": (-1, -1),
    #     "num_layers": [4, 6, 8],
    # },
    # {
    #     "layer_name": "GraphConv",
    #     "hidden_channels": [32, 64, 128],
    #     "in_channels": -1,
    #     "num_layers": [4, 6, 8],
    # },
    # {
    #     "layer_name": "Transformer",
    #     "hidden_channels": [32, 64, 128],
    #     "in_channels": -1,
    #     "num_layers": [4, 6, 8],
    # },
]

# %%
losses = defaultdict(dict)
for model in models:
    hidden_channels = model.get("hidden_channels")
    encoder_name = model.get("encoder_name")
    num_layers = model.get("num_layers")
    for hidden_channels_num in hidden_channels:
        for num_layers_num in num_layers:
            print("\n", encoder_name, "|", hidden_channels_num, "hidden_channels", "|", num_layers_num, "layers")
            my_model = ModelBuilderTrainerTester(
                encoder_name=encoder_name,
                train_data=train_data,
                val_data=val_data,
                test_data=test_data,
                hidden_channels=hidden_channels_num,
                in_channels=model.get("in_channels"),
                num_layers=num_layers_num,
            )
            loss, train_loss, val_loss, test_loss = my_model.train_test(epochs=5)
            if not losses[encoder_name].get(hidden_channels_num):
                losses[encoder_name][hidden_channels_num] = {}
            losses[encoder_name][hidden_channels_num][num_layers_num] = {
                "loss": loss,
                "train": train_loss,
                "val": val_loss,
                "test": test_loss,
            }
# Out:
#  GraphSAGE | 32 hidden_channels | 4 layers
# INITIALIZING MODEL-ENCODER
# INITIALIZED MODEL-ENCODER
# TO HETERO-ING MODEL-ENCODER
# TO HETERO MODEL-ENCODER
# c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\lib\site-packages\torch\nn\modules\lazy.py:178: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\movies_db\notebooks\7_PyG_models.ipynb Cell 29 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=7'>8</a> print("\n", encoder_name, "|", hidden_channels_num, "hidden_channels", "|", num_layers_num, "layers")
#       <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=8'>9</a> my_model = ModelBuilderTrainerTester(
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=9'>10</a>     encoder_name=encoder_name,
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=10'>11</a>     train_data=train_data,
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=15'>16</a>     num_layers=num_layers_num,
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=16'>17</a> )
# ---> <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=17'>18</a> loss, train_loss, val_loss, test_loss = my_model.train_test(epochs=5)
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=18'>19</a> if not losses[encoder_name].get(hidden_channels_num):
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=19'>20</a>     losses[encoder_name][hidden_channels_num] = {}
#
# c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\movies_db\notebooks\7_PyG_models.ipynb Cell 29 in ModelBuilderTrainerTester.train_test(self, epochs)
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=51'>52</a> def train_test(self, epochs):
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=52'>53</a>     # Due to lazy initialization, we need to run one model step so the number
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=53'>54</a>     # of parameters can be inferred:
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=54'>55</a>     with torch.no_grad():
# ---> <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=55'>56</a>         self.model.encoder(self.train_data.collect('x'), self.train_data.edge_index_dict)
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=56'>57</a>     print("Epoch:", end=" ")
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000027?line=57'>58</a>     for epoch in range(1, epochs):
#
# File c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\lib\site-packages\torch\nn\modules\module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\lib\site-packages\torch_geometric\nn\models\basic_gnn.py:125, in BasicGNN.forward(self, x, edge_index, *args, **kwargs)
#     123 xs: List[Tensor] = []
#     124 for i in range(self.num_layers):
# --> 125     x = self.convs[i](x, edge_index, *args, **kwargs)
#     126     if i == self.num_layers - 1 and self.jk_mode is None:
#     127         break
#
# File c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\lib\site-packages\torch\nn\modules\module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\lib\site-packages\torch_geometric\nn\conv\sage_conv.py:80, in SAGEConv.forward(self, x, edge_index, size)
#      77     x: OptPairTensor = (x, x)
#      79 # propagate_type: (x: OptPairTensor)
# ---> 80 out = self.propagate(edge_index, x=x, size=size)
#      81 out = self.lin_l(out)
#      83 x_r = x[1]
#
# File c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\lib\site-packages\torch_geometric\nn\conv\message_passing.py:270, in MessagePassing.propagate(self, edge_index, size, **kwargs)
#     267     if res is not None:
#     268         edge_index, size, kwargs = res
# --> 270 size = self.__check_input__(edge_index, size)
#     272 # Run "fused" message and aggregation (if applicable).
#     273 if (isinstance(edge_index, SparseTensor) and self.fuse
#     274         and not self._explain):
#
# File c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\lib\site-packages\torch_geometric\nn\conv\message_passing.py:155, in MessagePassing.__check_input__(self, edge_index, size)
#     152     the_size[1] = edge_index.sparse_size(0)
#     153     return the_size
# --> 155 raise ValueError(
#     156     ('`MessagePassing.propagate` only supports `torch.LongTensor` of '
#     157      'shape `[2, num_messages]` or `torch_sparse.SparseTensor` for '
#     158      'argument `edge_index`.'))
#
# ValueError: `MessagePassing.propagate` only supports `torch.LongTensor` of shape `[2, num_messages]` or `torch_sparse.SparseTensor` for argument `edge_index`.

# %%
losses["SAGE"]
# Out:
# {32: {4: {'loss': [20.831787109375,
#     19.353858947753906,
#     15.03516960144043,
#     6.389603614807129],
#    'train': [3.5240085124969482,
#     3.0998947620391846,
#     1.607228398323059,
#     1.9748286008834839],
#    'val': [3.5138299465179443,
#     3.0954549312591553,
#     1.6264253854751587,
#     1.992904782295227],
#    'test': [3.5186736583709717,
#     3.1002979278564453,
#     1.6299148797988892,
#     1.9827667474746704]},
#   6: {'loss': [20.972583770751953,
#     19.864927291870117,
#     12.546883583068848,
#     16.835134506225586],
#    'train': [3.5251197814941406,
#     2.810828924179077,
#     1.768379807472229,
#     2.1166858673095703],
#    'val': [3.5148892402648926,
#     2.8122479915618896,
#     1.7502182722091675,
#     2.131118059158325],
#    'test': [3.5197532176971436,
#     2.817340850830078,
#     1.7433792352676392,
#     2.1361522674560547]},
#   8: {'loss': [18.442577362060547,
#     15.043561935424805,
#     38.71215057373047,
#     11.809372901916504],
#    'train': [3.1006805896759033,
#     1.9748286008834839,
#     2.7157254219055176,
#     3.2292778491973877],
#    'val': [3.0944983959198,
#     1.9540181159973145,
#     2.7155675888061523,
#     3.2209086418151855],
#    'test': [3.0992603302001953,
#     1.9449282884597778,
#     2.720324993133545,
#     3.225602388381958]}},
#  64: {4: {'loss': [19.53548240661621,
#     16.639427185058594,
#     6.9051337242126465,
#     10.647523880004883],
#    'train': [3.2666773796081543,
#     1.119282603263855,
#     2.5547351837158203,
#     2.0524675846099854],
#    'val': [3.2592623233795166,
#     1.1411508321762085,
#     2.555532217025757,
#     2.06209397315979],
#    'test': [3.2640645503997803,
#     1.1400959491729736,
#     2.559985399246216,
#     2.0661966800689697]},
#   6: {'loss': [19.825490951538086,
#     15.985289573669434,
#     72.28372955322266,
#     13.487290382385254],
#    'train': [3.200134754180908,
#     1.9748286008834839,
#     2.9252381324768066,
#     3.398689031600952],
#    'val': [3.1936068534851074,
#     1.9824378490447998,
#     2.922022819519043,
#     3.388861656188965],
#    'test': [3.198411703109741,
#     1.972537875175476,
#     2.926730155944824,
#     3.3936147689819336]},
#   8: {'loss': [19.089651107788086,
#     19.45916748046875,
#     18.3587646484375,
#     18.393962860107422],
#    'train': [1.960920810699463,
#     3.4328362941741943,
#     3.436128616333008,
#     3.4043617248535156],
#    'val': [1.938795804977417,
#     3.4227137565612793,
#     3.426079750061035,
#     3.3946492671966553],
#    'test': [1.9301657676696777,
#     3.4274966716766357,
#     3.4308695793151855,
#     3.3994367122650146]}},
#  128: {4: {'loss': [19.834640502929688,
#     7.653164863586426,
#     3644.52294921875,
#     8.522464752197266],
#    'train': [2.0146377086639404,
#     1.9748286008834839,
#     1.107413649559021,
#     3.269015312194824],
#    'val': [2.026401996612549,
#     1.9943498373031616,
#     1.1227993965148926,
#     3.2606067657470703],
#    'test': [2.030714511871338,
#     1.984390377998352,
#     1.1196503639221191,
#     3.265333652496338]},
#   6: {'loss': [18.541500091552734,
#     24.256324768066406,
#     17.798114776611328,
#     17.54465103149414],
#    'train': [1.9748286008834839,
#     3.3798999786376953,
#     3.3555824756622314,
#     3.338200569152832],
#    'val': [1.9745664596557617,
#     3.3690381050109863,
#     3.3455753326416016,
#     3.3283708095550537],
#    'test': [1.9647815227508545,
#     3.3736917972564697,
#     3.3502867221832275,
#     3.3330795764923096]},
#   8: {'loss': [20.250232696533203,
#     741.6278686523438,
#     19.65930938720703,
#     19.34156036376953],
#    'train': [1.9748286008834839,
#     3.5251197814941406,
#     3.5229973793029785,
#     3.4880547523498535],
#    'val': [1.9943498373031616,
#     3.5148892402648926,
#     3.512829542160034,
#     3.478151321411133],
#    'test': [1.984390377998352,
#     3.5197532176971436,
#     3.5176970958709717,
#     3.4830093383789062]}}}

# %%
fig = plt.figure(figsize=(20, 7))

index = 1
for layer in layers:
    layer_models = list(filter(lambda x: x.get("layer_name")==layer, models))
    if not len(layer_models):
        continue
    model = layer_models[0]
    hidden_channels_nums = model.get("hidden_channels")
    layers_nums = model.get("num_layers")
    ax = fig.add_subplot(1, 4, index)
    ax.title.set_text(layer)
    ax.set_ylim(0.0, 10.0)
    legend = []
    hidden_channels_num = 32
    for hidden_channels_num in hidden_channels_nums:
        for layers_num in layers_nums:
            loss, train, val, test = losses[layer][hidden_channels_num][layers_num].values()
            ax.plot(loss)
            ax.plot(train)
            ax.plot(val)
            ax.plot(test)
            # legend += [f"loss {hidden_channels_num} {layers_num}"]
            legend += [f"loss {hidden_channels_num} {layers_num}", f"train loss {hidden_channels_num} {layers_num}", f"val loss {hidden_channels_num} {layers_num}", f"test loss {hidden_channels_num} {layers_num}"]
    ax.legend(legend)
    index += 1

# %%
my_model = ModelBuilderTrainerTester(
                encoder_name=encoder_name,
                train_data=train_data,
                val_data=val_data,
                test_data=test_data,
            )
# Out:
# ---------------------------------------------------------------------------
# TraceError                                Traceback (most recent call last)
# c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\movies_db\notebooks\7_PyG_models.ipynb Cell 32 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=0'>1</a> my_model = ModelBuilderTrainerTester(
#       <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=1'>2</a>                 encoder_name=encoder_name,
#       <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=2'>3</a>                 train_data=train_data,
#       <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=3'>4</a>                 val_data=val_data,
#       <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=4'>5</a>                 test_data=test_data,
#       <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=5'>6</a>             )
#
# c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\movies_db\notebooks\7_PyG_models.ipynb Cell 32 in ModelBuilderTrainerTester.__init__(self, train_data, val_data, test_data, in_channels, hidden_channels, out_channels, num_layers, encoder_name)
#       <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=1'>2</a> def __init__(self, train_data, val_data, test_data, in_channels=-1, hidden_channels=32, out_channels=32, num_layers=4, encoder_name="GraphSAGE"):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=2'>3</a>     model = Model(
#       <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=3'>4</a>         in_channels=in_channels,
#       <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=4'>5</a>         hidden_channels=hidden_channels,
#       <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=5'>6</a>         out_channels=out_channels,
#       <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=6'>7</a>         encoder_name=encoder_name,
#       <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=7'>8</a>         num_layers=num_layers,
#       <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=8'>9</a>     ).to(device)
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=9'>10</a>     self.model = model
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=10'>11</a>     self.optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
#
# c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\movies_db\notebooks\7_PyG_models.ipynb Cell 32 in Model.__init__(self, encoder_name, in_channels, hidden_channels, out_channels, num_layers, dropout)
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=14'>15</a> self.hidden_channels = hidden_channels
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=15'>16</a> self.out_channels = out_channels
# ---> <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=16'>17</a> self.encoder = to_hetero(self.encoder, data.metadata(), aggr='sum')
#      <a href='vscode-notebook-cell:/c%3A/Users/GiannisAthanasiou/Desktop/diploma/repo/diploma/movies_db/notebooks/7_PyG_models.ipynb#ch0000032?line=17'>18</a> self.decoder = EdgeDecoder(hidden_channels)
#
# File c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\lib\site-packages\torch_geometric\nn\to_hetero_transformer.py:110, in to_hetero(module, metadata, aggr, input_map, debug)
#      19 def to_hetero(module: Module, metadata: Metadata, aggr: str = "sum",
#      20               input_map: Optional[Dict[str, str]] = None,
#      21               debug: bool = False) -> GraphModule:
#      22     r"""Converts a homogeneous GNN model into its heterogeneous equivalent in
#      23     which node representations are learned for each node type in
#      24     :obj:`metadata[0]`, and messages are exchanged between each edge type in
#    (...)
#     108             transformation in debug mode. (default: :obj:`False`)
#     109     """
# --> 110     transformer = ToHeteroTransformer(module, metadata, aggr, input_map, debug)
#     111     return transformer.transform()
#
# File c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\lib\site-packages\torch_geometric\nn\to_hetero_transformer.py:134, in ToHeteroTransformer.__init__(self, module, metadata, aggr, input_map, debug)
#     126 def __init__(
#     127     self,
#     128     module: Module,
#    (...)
#     132     debug: bool = False,
#     133 ):
# --> 134     super().__init__(module, input_map, debug)
#     136     unused_node_types = get_unused_node_types(*metadata)
#     137     if len(unused_node_types) > 0:
#
# File c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\lib\site-packages\torch_geometric\nn\fx.py:73, in Transformer.__init__(self, module, input_map, debug)
#      66 def __init__(
#      67     self,
#      68     module: Module,
#      69     input_map: Optional[Dict[str, str]] = None,
#      70     debug: bool = False,
#      71 ):
#      72     self.module = module
# ---> 73     self.gm = symbolic_trace(module)
#      74     self.input_map = input_map
#      75     self.debug = debug
#
# File c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\lib\site-packages\torch_geometric\nn\fx.py:241, in symbolic_trace(module, concrete_args)
#     237     def is_leaf_module(self, module: Module, *args, **kwargs) -> bool:
#     238         # TODO We currently only trace top-level modules.
#     239         return not isinstance(module, torch.nn.Sequential)
# --> 241 return GraphModule(module, Tracer().trace(module, concrete_args))
#
# File c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\lib\site-packages\torch\fx\_symbolic_trace.py:566, in Tracer.trace(self, root, concrete_args)
#     564     for module in self._autowrap_search:
#     565         _autowrap_check(patcher, module.__dict__, self._autowrap_function_ids)
# --> 566     self.create_node('output', 'output', (self.create_arg(fn(*args)),), {},
#     567                      type_expr=fn.__annotations__.get('return', None))
#     569 self.submodule_paths = None
#     571 return self.graph
#
# File c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\lib\site-packages\torch_geometric\nn\models\basic_gnn.py:126, in BasicGNN.forward(self, x, edge_index, args, kwargs)
#     124 for i in range(self.num_layers):
#     125     x = self.convs[i](x, edge_index, *args, **kwargs)
# --> 126     if i == self.num_layers - 1 and self.jk_mode is None:
#     127         break
#     128     if self.act_first:
#
# File c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\lib\site-packages\torch\fx\proxy.py:254, in Proxy.__iter__(self)
#     251 if inst.opname == 'UNPACK_SEQUENCE':
#     252     return (self[i] for i in range(inst.argval))  # type: ignore[index]
# --> 254 return self.tracer.iter(self)
#
# File c:\Users\GiannisAthanasiou\Desktop\diploma\repo\diploma\environ\lib\site-packages\torch\fx\proxy.py:163, in TracerBase.iter(self, obj)
#     156 @compatibility(is_backward_compatible=True)
#     157 def iter(self, obj: 'Proxy') -> Iterator:
#     158     """Called when a proxy object is being iterated over, such as
#     159     when used in control flow.  Normally we don't know what to do because
#     160     we don't know the value of the proxy, but a custom tracer can attach more
#     161     information to the graph node using create_node and can choose to return an iterator.
#     162     """
# --> 163     raise TraceError('Proxy object cannot be iterated. This can be '
#     164                      'attempted when the Proxy is used in a loop or'
#     165                      ' as a *args or **kwargs function argument. '
#     166                      'See the torch.fx docs on pytorch.org for a '
#     167                      'more detailed explanation of what types of '
#     168                      'control flow can be traced, and check out the'
#     169                      ' Proxy docstring for help troubleshooting '
#     170                      'Proxy iteration errors')
#
# TraceError: Proxy object cannot be iterated. This can be attempted when the Proxy is used in a loop or as a *args or **kwargs function argument. See the torch.fx docs on pytorch.org for a more detailed explanation of what types of control flow can be traced, and check out the Proxy docstring for help troubleshooting Proxy iteration errors
