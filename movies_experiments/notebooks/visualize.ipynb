# %%
import pathlib
import os
import os.path as osp
import sys
import argparse
parent_path = pathlib.Path(os.getcwd()).parent.absolute()
sys.path.append(str(parent_path))
from utils.visualize import plot_results, plot_loss, plot_test, plot_train, plot_val

# %%
import json

results_path = "../results/['SAGE', 'GAT', 'GraphConv']__encoder_5_5__decoder_5_5__20_epochs__[0.012]_lrs.json"
with open(results_path) as f:
    losses = json.load(f)
    plot_loss(losses, ylim=15)

# %%
plot_train(losses, ylim=5)

# %%
plot_val(losses, ylim=5)

# %%
plot_test(losses, ylim=5)
