# %% [markdown]
# # First approach on GNNs

# %% [markdown]
# ## Initialize the DB connection

# %%
from py2neo import Graph

graph = Graph(
    # "bolt://0.0.0.0:7687",
    "bolt://localhost:7687",
    # "http://0.0.0.0:7687",
    # "bolt+s://localhost:7687",
    auth=("neo4j", "admin"),
    # name="neo4j"
)

try:
    graph.run("Match () Return 1 Limit 1")
    print('ok')
except Exception as e:
    print(e)
    print(e.with_traceback)
    print('not ok')
# Out:
# ok

# %% [markdown]
# ## Build PyG graph instance

# %% [markdown]
# ### Imports

# %%
import torch
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from torch_geometric.data import HeteroData
from torch_geometric.transforms import RandomLinkSplit, ToUndirected
from torch.nn import Linear
from torch_geometric.nn import SAGEConv, to_hetero
import torch.nn.functional as F

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Helper methods

# %%
def fetch_data(query):
    result = graph.run(query)
    return pd.DataFrame([r.values() for r in result], columns=result.keys())

# %%
# https://github.com/pyg-team/pytorch_geometric/blob/master/examples/hetero/load_csv.py
# https://towardsdatascience.com/integrate-neo4j-with-pytorch-geometric-to-create-recommendations-21b0b7bc9aa

def load_node(query, index_col, encoders=None):
    df = fetch_data(query)
    df.set_index(index_col, inplace=True)
    
    # define node mappings node: index
    mapping = { index: i for i, index in enumerate(df.index.unique()) }
    
    # define node features
    x = None
    if encoders is not None:
        try:
            print("items:", encoders.items())
            xs = [encoder(df[col]) for col, encoder in encoders.items()]
            x = torch.cat(xs, dim=-1)
        except Exception as err:
            print(err)
            print("------------------------------")
            print(df)
            print("------------------------------")
            raise Exception
    return x, mapping

# %%
# https://github.com/pyg-team/pytorch_geometric/blob/master/examples/hetero/load_csv.py
# https://towardsdatascience.com/integrate-neo4j-with-pytorch-geometric-to-create-recommendations-21b0b7bc9aa

def load_edge(query, src_index_col, src_mapping, dst_index_col, dst_mapping, encoders=None):
    df = fetch_data(query)
    
    # define edge index
    src = [src_mapping[index] for index in df[src_index_col]]
    dst = [dst_mapping[index] for index in df[dst_index_col]]
    edge_index = torch.tensor([src, dst])
       
    # define edge features
    edge_attr = None
    if encoders is not None:
        edge_attrs = [encoder(df[col]) for col, encoder in encoders.items()]
        edge_attr = torch.cat(edge_attrs, dim=-1)
    
    return edge_index, edge_attr

# %% [markdown]
# ### Encoders

# %%
# https://github.com/pyg-team/pytorch_geometric/blob/master/examples/hetero/load_csv.py

class SequenceEncoder(object):
    # The 'SequenceEncoder' encodes raw column strings into embeddings.
    def __init__(self, model_name='all-MiniLM-L6-v2', device=None):
        self.device = device
        self.model = SentenceTransformer(model_name, device=device)

    @torch.no_grad()
    def __call__(self, df):
        x = self.model.encode(df.values, show_progress_bar=True,
                              convert_to_tensor=True, device=self.device)
        return x.cpu()

# %%
# https://github.com/pyg-team/pytorch_geometric/blob/master/examples/hetero/load_csv.py
# https://colab.research.google.com/github/tomasonjo/blogs/blob/master/pyg2neo/Movie_recommendations.ipynb#scrollTo=n1QiEzKZ348J

class IdentityEncoder(object):
    # The 'IdentityEncoder' takes the raw column values and converts them to
    # PyTorch tensors.
    def __init__(self, dtype=None, is_list=False):
        self.dtype = dtype
        self.is_list = is_list

    def __call__(self, df):
        if self.is_list:
            return torch.stack([torch.tensor(el) for el in df.values])
        return torch.from_numpy(df.values).to(self.dtype)

# %% [markdown]
# ### Users nodes

# %%
users_query = """
    MATCH (u:User) RETURN u.id as userId, u.name as name
"""

user_x, user_mapping = load_node(
    users_query,
    index_col='userId',
    encoders={
        'name': SequenceEncoder(),
    }
)
# Out:
# items: dict_items([('name', <__main__.SequenceEncoder object at 0x0000027320A638E0>)])
# Batches:   0%|          | 0/2167 [00:00<?, ?it/s]

# %%
user_mapping
# Out:
# {'A5TA1NJOC0PJ5': 0,
#  'A1TJICB7VLGQKL': 1,
#  'A80M2286B7STE': 2,
#  'A2TM2MAA8IT34U': 3,
#  'AQGWT465GTEJG': 4,
#  'AA0ACUPEPT1RN': 5,
#  'A1JM3NL9GSQ17N': 6,
#  'A3C5DYTUXUCL0S': 7,
#  'A2H3NOCLLEPOKQ': 8,
#  'A3A2HRW0GR4EWU': 9,
#  'A16UTJN8DODY6N': 10,
#  'A2P0254ZZ42ZOJ': 11,
#  'ACB9GSMY2GY0O': 12,
#  'A3DNSZT2HIB30J': 13,
#  'A2Q8QWVIZM213M': 14,
#  'ABVND860D55AJ': 15,
#  'A267CAHUU3HOPQ': 16,
#  'ANNS6DSY390Z2': 17,
#  'A7DS7JE3D53XW': 18,
#  'ASZO5WJA6FVVH': 19,
#  'A1KU7EEUGYOJYD': 20,
#  'A1907XNEJPEZEI': 21,
#  'A3U7B0EKSK16MQ': 22,
#  'A3OCOP75PMY097': 23,
#  'AS02PGU8BFX2': 24,
#  'A1TYR5GO9YE60D': 25,
#  'AFO1CM5HMAEA6': 26,
#  'A2J6AVSVGGFEJP': 27,
#  'A18WA88B995ZT7': 28,
#  'A36WKQ76TJCCYW': 29,
#  'A1S0WV2WXFZRKI': 30,
#  'ASCTK6A1JGPM8': 31,
#  'AFJE85Y0YPOVY': 32,
#  'A6D30HQK1YJE8': 33,
#  'AE1LNE5A2BO74': 34,
#  'AOOZO1BRJRCVY': 35,
#  'A1I6F8COVMNYAH': 36,
#  'A1V0MU46D12JST': 37,
#  'AMDPRJ5R8DSUO': 38,
#  'A3UGHH4IFF5CV3': 39,
#  'A3G5ST2S43IB65': 40,
#  'ARNM7L2CEQZHU': 41,
#  'A2T0L8BI7IEH5Q': 42,
#  'A3AX4BN9YVIU5J': 43,
#  'A1PHTBLZAQWWG': 44,
#  'A2RYSCZOPEXOCQ': 45,
#  'A1FSPH5TCDXQO4': 46,
#  'A3FC1W71TBNM0P': 47,
#  'A1R2ZOLD7VWPWB': 48,
#  'AWBHTIFQZDYDB': 49,
#  'A0203113HC2KF1AHJHOV': 50,
#  'A29VJHWGQMI3L1': 51,
#  'A2A2KNKIQHSOFK': 52,
#  'A1C915H2JH5Q2F': 53,
#  'AMMFH8V3JD5WD': 54,
#  'A3UHZG4PNC1EEX': 55,
#  'A2GDK3U9V823PW': 56,
#  'A23E118ZEH1987': 57,
#  'A1PEREM420IQTC': 58,
#  'ADPHXHWSY2AVP': 59,
#  'A3HIKT4301GRR2': 60,
#  'A140NZXGO4CWZR': 61,
#  'AVWQ9F2IXREHV': 62,
#  'A1C7B81WB2PW1G': 63,
#  'A130PM0TZ2U1JQ': 64,
#  'A2XDDAOMK3KA18': 65,
#  'A2XGCE5UZK0DAG': 66,
#  'AM37QEJBT15TR': 67,
#  'A1BAONZQ70R96D': 68,
#  'A1HDRRKHVSJ7U8': 69,
#  'A2V8PVJNLQWDWT': 70,
#  'AOOA2FYJXP81E': 71,
#  'A2FNH573KJMC1M': 72,
#  'A1HYU0QTCAP985': 73,
#  'AHDLKRFLY28N2': 74,
#  'A39UQJJ2MX3UA0': 75,
#  'A3PUCC1JC9NZTF': 76,
#  'A327UGFMAU3WRS': 77,
#  'A3TB9HNQR54B5V': 78,
#  'AQL2WVOAADPE2': 79,
#  'A1YS1OPB9J3G81': 80,
#  'A1SIKQ2Y1KV8ZE': 81,
#  'A2E8HXYLD5IHWZ': 82,
#  'A2QMN6YG9OSR2Y': 83,
#  'A141OPVE376YFI': 84,
#  'AKYZT5W6CV49J': 85,
#  'AQQQ96CU68IHQ': 86,
#  'A2BGZ52M908MJY': 87,
#  'A1XCHEMKKMVFPR': 88,
#  'A2YRLJOWK3DIQE': 89,
#  'A3UCRIDC2A2I9X': 90,
#  'A2Y7WMR7TZCE0': 91,
#  'A1KER6XPDE5JBH': 92,
#  'A2L4CDVO926V3P': 93,
#  'AGDF79PEQNXAX': 94,
#  'A229VYYCMD9MEO': 95,
#  'A2GRPYBCEYKNSB': 96,
#  'ARGYCU5SJ8RNM': 97,
#  'A1NEXEMSZVVDK3': 98,
#  'AI05UTP3UL8G9': 99,
#  'A198CCH4NNLI2E': 100,
#  'A21VV3WL2OQA6': 101,
#  'A2WL8401W82OTA': 102,
#  'A2KEO12W2C0FUB': 103,
#  'A321L3KPZGTCXT': 104,
#  'A3DGHFV9UZA29C': 105,
#  'A2EZTJ6GUTJNO5': 106,
#  'A1IQDRTXYP2XNJ': 107,
#  'A1WOOTTPNBO83F': 108,
#  'AFSXEZEI6JZF5': 109,
#  'A1M4NJYP0WNL8Q': 110,
#  'A3C1YNONTO2OLL': 111,
#  'AO34DJGYM95XT': 112,
#  'A32183CE48CR78': 113,
#  'A1PSML66J3JOJ0': 114,
#  'A36TGVA9PBML14': 115,
#  'AH5QTKOP4PHE4': 116,
#  'A3V6I06Z5QU0ZY': 117,
#  'A2HNJMAB34AAJA': 118,
#  'A2IKT8UFD842FS': 119,
#  'A3HFM78UB91O4C': 120,
#  'A3N8WXO0J4V7SX': 121,
#  'A1ZJVEBTWAYB51': 122,
#  'A3OIKIXZSG7QXF': 123,
#  'A31YC1ZG5QI5WN': 124,
#  'A1Z0W20YCPCMSD': 125,
#  'AQP3AFEATAWUQ': 126,
#  'AESRCV05POSWP': 127,
#  'A13GSTHT3N89WZ': 128,
#  'ALA73JZ2T9CKE': 129,
#  'A13GOEA9FXMQ75': 130,
#  'A1VXOKOGWQR599': 131,
#  'A1D6VU2D8ZWJ0': 132,
#  'A3SLZ7R4SEDXVI': 133,
#  'A2M41EN1CP8QD3': 134,
#  'A1HFXWD5DNMF72': 135,
#  'A216YV7RI8SDSM': 136,
#  'A3BZDOE05C4TJK': 137,
#  'A3D1B3Y0CBB785': 138,
#  'A22WKHXY1UAWFN': 139,
#  'A2AZ5DEZNDKY4O': 140,
#  'A2JA7WNJJS6PUG': 141,
#  'A209G69UT4X1J9': 142,
#  'A3SZ3YQ11OWSWI': 143,
#  'AZLLO1AGAIRI5': 144,
#  'A2STMKMCLZJOZX': 145,
#  'A2AUWN4TRH5DB2': 146,
#  'A2LYDPOLZ2AXSN': 147,
#  'AIZ0BVYD6FUUH': 148,
#  'A31ILO54F8R43W': 149,
#  'AIWONTSZOI4AL': 150,
#  'A34A1UP40713F8': 151,
#  'A3VFL9IPJUYB9H': 152,
#  'A3NFHDFAJVLRHO': 153,
#  'A1YXUK0CR6JD8V': 154,
#  'ALYNYSET2GS5D': 155,
#  'A1CUTTK2OXJPT7': 156,
#  'A16ZIY7J87ZFZW': 157,
#  'A1JSODTH1YC4IO': 158,
#  'A27JVXM883LMLA': 159,
#  'A1JK6EOHPXBQ4R': 160,
#  'A3A9PRPEG3ONIE': 161,
#  'A1WIZFCGRSFINB': 162,
#  'A2WPZSHZFTCIVU': 163,
#  'A2JFMNPLDLANC7': 164,
#  'AAPNO3ZYUMYG8': 165,
#  'A1QOZ5Y1C2VJJN': 166,
#  'AVQDTDBWW08B6': 167,
#  'AQHISYMV31P3W': 168,
#  'AZMON54INRJ6F': 169,
#  'A23K1TD0JR7OF5': 170,
#  'A1PM1J2DP4FYVN': 171,
#  'A2DN9VP5SYSPI6': 172,
#  'A3PV5UVGJRM7RP': 173,
#  'A2OY0RKXHQVD3E': 174,
#  'AZTY1YL893VCD': 175,
#  'A14B0ILAG88P66': 176,
#  'A20I37YVDJ54VZ': 177,
#  'A1MJH348AZ3LG4': 178,
#  'ASQICPWK96ANO': 179,
#  'A3IPKGZ51HTSBF': 180,
#  'A1IM4SVKI29L5T': 181,
#  'A29BYL1GPW6B6E': 182,
#  'ACOOW6BZGMNZZ': 183,
#  'A2KVVPBG96XSTB': 184,
#  'A4T91S4N8LZAC': 185,
#  'A22UI6FA3QFCZW': 186,
#  'A39K4UULVIFPIU': 187,
#  'A3JYPVFEK121PJ': 188,
#  'AYCP69PDJNYNU': 189,
#  'A33E0P4SH55OL': 190,
#  'A1ESZNDNWE2UMG': 191,
#  'A1ZNXMDN7RD671': 192,
#  'A2Y20SWW9I3OM8': 193,
#  'A1CWVY6UFAVYMB': 194,
#  'AWKBFSFLYSN6H': 195,
#  'A3SK6BFRXFQ9HA': 196,
#  'A2W5YSA58C6ZV5': 197,
#  'A24ISG68G7UOC5': 198,
#  'A1DECOV45AA7G7': 199,
#  'A2I0G4FMJZCZID': 200,
#  'A3Q36LKGL5YX3U': 201,
#  'A1AJWL0YRYR83K': 202,
#  'A2EATL6WZE85G2': 203,
#  'A208CC3SOOWWP': 204,
#  'A3M4AL59MDR8HN': 205,
#  'A1H2O2SXYS8B9C': 206,
#  'A2AH5CCHRG9KLW': 207,
#  'A12QG9XN1BNI7': 208,
#  'A2DG5B5WFOEXPI': 209,
#  'A2JMR58XNMG550': 210,
#  'A27YOV6ZABYA5L': 211,
#  'A3DABWSGHUVOQV': 212,
#  'A1IWJAPC3CQTMS': 213,
#  'A3J26MZXRPKQED': 214,
#  'A1Z8L5IFC0R7JH': 215,
#  'ADEFSK37XQ6SF': 216,
#  'A2QCZGSXKO1ER1': 217,
#  'ALE9A951PJEOA': 218,
#  'A19VLZ62RD31GR': 219,
#  'A103YZL87LWXB8': 220,
#  'A3PU2TKU7QXF3E': 221,
#  'A37175N6AX3K76': 222,
#  'AKBXDC1LOYV64': 223,
#  'AD92QG51NM1A8': 224,
#  'A3D5JTM5LPQBFS': 225,
#  'A8KT21XWV8CEQ': 226,
#  'A12BLI7J25S6P7': 227,
#  'A1KLFNG7VKDG6H': 228,
#  'AEUIOOXIEW8LE': 229,
#  'A3OFXSOBAMCGOR': 230,
#  'A1P6NRWDD1NT4B': 231,
#  'A2ZZJ611VDQ722': 232,
#  'ABHDMOT01KG4S': 233,
#  'ALENNU5ZWXV3W': 234,
#  'ADC91NTEBOTZ8': 235,
#  'A1FL1S2GPNLUMJ': 236,
#  'AIAU6UX41ZUB3': 237,
#  'A3Q24Q4Q0008AB': 238,
#  'A29PO5HKEE1K8W': 239,
#  'A27HGGFYTJOF36': 240,
#  'A1TVTDKNMSQ7XU': 241,
#  'A1091KBRJBQDKF': 242,
#  'A2YY2023P7KYK3': 243,
#  'A18HEGPTB7R8WI': 244,
#  'AQSHU6E1X7TQV': 245,
#  'A32Y3WCBSSZ1O9': 246,
#  'A20MVMF16MADUK': 247,
#  'A3MS7T44JO5Y0C': 248,
#  'A24F67VABM0BEB': 249,
#  'A3S7ECT3VU3BY7': 250,
#  'A2FRWZKVHR05I9': 251,
#  'A195D7ESO15UTH': 252,
#  'A1WGQV1MHCMYKY': 253,
#  'AWUPRDMC1J6UP': 254,
#  'A3VYECE9MYJ16': 255,
#  'A2YWKGOCQV9O3W': 256,
#  'A2LKNA1T2JSWHF': 257,
#  'A1O0UZWSZPRNLJ': 258,
#  'A1W0PMHGAB4N5B': 259,
#  'A1M0VEHPQMUXW7': 260,
#  'A2KLWYHJ26O2Z9': 261,
#  'A2NSHFYO38WRIM': 262,
#  'ARB94UKTX6OVK': 263,
#  'A1LF5ZC278YTKS': 264,
#  'A35O29DECBXK3N': 265,
#  'A3PGGI7A6XCNF1': 266,
#  'A1QWZNRS875RW': 267,
#  'A1NEABWBSF7W0S': 268,
#  'A2KQEUTGMHZUH5': 269,
#  'AIQ4VMVNXMWTH': 270,
#  'A2Q0FEVFEITNRS': 271,
#  'A1CURXNCXZXJFI': 272,
#  'A2TKGU8HFRDZNR': 273,
#  'ADLNYNSGWBNA': 274,
#  'A1SXGNMNFBFYSR': 275,
#  'A3C6BRGGVKR1JV': 276,
#  'A3EVWL8ZPBMHM9': 277,
#  'AMIFLZC7XGDM0': 278,
#  'A10COP399MYGPO': 279,
#  'ABRVBYHNKZAPF': 280,
#  'A307RZNJ5L3OWQ': 281,
#  'A3QTH2QU3YABDJ': 282,
#  'A24BO8G8VYGYFK': 283,
#  'A14RDCIIDJ20BP': 284,
#  'A1OBS2NCH8W6IF': 285,
#  'A269T1V0YV4W6S': 286,
#  'A1T48BIP80VJ87': 287,
#  'A6EGZMOY951ZO': 288,
#  'AE0D80Z46PFJE': 289,
#  'A2WRQKKOKU1YGB': 290,
#  'A3MPTSF457K012': 291,
#  'A11JDGZJEFDB7S': 292,
#  'A2T6ASXYZCUFLG': 293,
#  'A3K4VN0MHW084P': 294,
#  'A38SVQGA69TC46': 295,
#  'A1TYYX51BBDYJ5': 296,
#  'A3MHM37DM7ZRLI': 297,
#  'A14CCPBJHKBHSF': 298,
#  'AANGXJHEZFK2G': 299,
#  'A3GL9U8YB3MGEP': 300,
#  'A2JJJSMEHEV0MC': 301,
#  'A357YUM9MOCJT': 302,
#  'A37IV22LZH1JSK': 303,
#  'A1KTVNLJ94B7KB': 304,
#  'AA4I4KEFV6AYS': 305,
#  'A3QNI8TAY8AHGZ': 306,
#  'A2SKKCL34WFDQ5': 307,
#  'A323ZG3KDIR8I4': 308,
#  'A2LX43TPP277PJ': 309,
#  'AA4X7P4JKAYBO': 310,
#  'A1N23XEHA6L0FV': 311,
#  'A1REXZT8V6HUYL': 312,
#  'A10LM7HZ6U1U9V': 313,
#  'A2QVFHIWOKXXEJ': 314,
#  'A39L6CGP0M44Z4': 315,
#  'A2N8Q51U0TDV5J': 316,
#  'AEA16OHAN0HL1': 317,
#  'A2LPO92QL7MATY': 318,
#  'AB2TGTMRUX8LV': 319,
#  'A2JAE5DFH0RH1K': 320,
#  'A1ZFUHFVW48CT2': 321,
#  'A3637JAQYHAAZT': 322,
#  'A20I1RDZLOGXZ4': 323,
#  'A3QQ236ZNET6A1': 324,
#  'AIY76XTWQRXBC': 325,
#  'A34VA4JHY1FUY': 326,
#  'A2KAH8FD4JNBX4': 327,
#  'AJ86MYUT3VJE5': 328,
#  'A6FIAB28IS79': 329,
#  'A1W9UJ28FABCBT': 330,
#  'A3D4ZCHVFF5GF2': 331,
#  'AGXH8DR5LB2JK': 332,
#  'A39D37KREKB3BD': 333,
#  'A1WIML2HURB4FS': 334,
#  'A29ZG8IHLO6F9R': 335,
#  'AMTL4PQ4QNC4S': 336,
#  'A3PAQUHVR4HQ69': 337,
#  'A38TXCFYJ4O27G': 338,
#  'A1JVQLIVP4D9ER': 339,
#  'A39PKWGXAGZPSN': 340,
#  'AK9PD28JWKOR8': 341,
#  'A1X48RDTFGEGL7': 342,
#  'A37WG73R5YAXJM': 343,
#  'A8009FDBLWMJV': 344,
#  'A30L3H02HXXR0Y': 345,
#  'A14YMNRZYJ7VPC': 346,
#  'A1MLWN7U8Z0AJP': 347,
#  'A1OQN5DKC0HR4R': 348,
#  'A249G55C6DJ583': 349,
#  'A38WORKGWPXKGV': 350,
#  'A3UYVAGQF824JG': 351,
#  'A5C151WZB7LHC': 352,
#  'ABKRIE4VSG8ZL': 353,
#  'AOBKPL3VXX54S': 354,
#  'A8DMVBFN8LWYS': 355,
#  'A1MDMYVR33X3G5': 356,
#  'A3FKGKUCI3DG9U': 357,
#  'A1MM4OVSUG7GAA': 358,
#  'A1W7PTKW5E9IWC': 359,
#  'A1OFUVZPSLKDHL': 360,
#  'A2ACQRT3A8HVCX': 361,
#  'A3NYSM5ERZIDTI': 362,
#  'A18ETS9RMLXDWV': 363,
#  'ASEWC3SAWU5RU': 364,
#  'A2WXOVQMOGNITO': 365,
#  'AN13J6SXS3KH9': 366,
#  'A1JGUD5NTK39R0': 367,
#  'AU900ND3IL7GC': 368,
#  'A3RZ245SGWVX8S': 369,
#  'ADCHPS3R5R64D': 370,
#  'AHD79V5R3LCU6': 371,
#  'A1WS6YDOAOFUXB': 372,
#  'A1UQL2RGF55E7K': 373,
#  'A3EUDB6LR7S7IN': 374,
#  'A3HO3H4TUWZRC6': 375,
#  'A230980T2K5AG3': 376,
#  'A423JPSP7TT4A': 377,
#  'A379MGEF4ZRT1A': 378,
#  'A1F6K29VJ5Z7ZD': 379,
#  'A2OWHHUQXC3R80': 380,
#  'A1ACVREYV67EPI': 381,
#  'AYKKS0HAP5VN6': 382,
#  'A2YLNZCUI1KJUP': 383,
#  'A1DW47ECH7PCGM': 384,
#  'A24RLCF83HITYN': 385,
#  'A2508J7J4WPY3K': 386,
#  'AD5C2Y5MFXHN5': 387,
#  'A3E4MQZNDI995K': 388,
#  'A8YKW3TCCNXZV': 389,
#  'A3PQRJT5CSUY5N': 390,
#  'A3FMC7N2H1LT1V': 391,
#  'A3IKQZK96VYUVK': 392,
#  'A3PMRVMALOUYB': 393,
#  'A3DZ9G8CYVHK76': 394,
#  'A267OZ14Y4UTC1': 395,
#  'A1FG8SNB674HDQ': 396,
#  'A36IOP5N8RXFW': 397,
#  'A35YM1ZG3S01P5': 398,
#  'A3LSBUO0I66Y3C': 399,
#  'AJE724Y9BXBC0': 400,
#  'ABPUWXA92L6DG': 401,
#  'A3KWVE07S1Y0SA': 402,
#  'A15WXEDQ1OPA3G': 403,
#  'A1DRAMIVUY8X2Y': 404,
#  'A2F8ZXAJMFX7BV': 405,
#  'A1JY42ZVRQ96E4': 406,
#  'A168ZAQIN5KWIT': 407,
#  'A3W44HA4UK3Y30': 408,
#  'A1SVS44HS1IO8M': 409,
#  'AX3BN4FBGIQEH': 410,
#  'A36R3UYP81GTH3': 411,
#  'ABIS9FCL7CQJQ': 412,
#  'A2B4THKYD5K5R1': 413,
#  'A1WEAFADMQHV0J': 414,
#  'A2ILRF3S8SIFW0': 415,
#  'A23TB6M8L42YR0': 416,
#  'AQNJL23CGGCZK': 417,
#  'A1N859IHIHU8D9': 418,
#  'A2TXVUGA5TZYZI': 419,
#  'A3SXEZVH2IKSFP': 420,
#  'A3O3CK434X3D1': 421,
#  'A23LTLN15K2FBC': 422,
#  'A3DJPLT67G19DJ': 423,
#  'A3C307IOXUQVR7': 424,
#  'A2LLWUTONBD6S2': 425,
#  'A1TCIQR4U3G0F0': 426,
#  'A2FEXK7DIIOGTU': 427,
#  'A1E8GU7DVTBOKQ': 428,
#  'A1DLX1B6WJ0NQ': 429,
#  'A37YOCM4BZK8JV': 430,
#  'A1FTAX5YNDD5FJ': 431,
#  'A34XJ7EFTM325Z': 432,
#  'AVDTTR1GQ7XWK': 433,
#  'A2FSHMUOIGIDBN': 434,
#  'AR6APXLK7TJU2': 435,
#  'AWW26H4NDCIE3': 436,
#  'A1J541IZNNTNWK': 437,
#  'A1F5KQAR0M9ZDL': 438,
#  'A3AB6PLM9EK9H2': 439,
#  'A157J1M05GIZ9D': 440,
#  'ACEGRQ18JVLQP': 441,
#  'A3EY1Y4GU657DP': 442,
#  'A2T7ZVW93V6TXP': 443,
#  'A1BN4T6ES7FX31': 444,
#  'A1O50P8MZ5GS01': 445,
#  'A3SEVII9EH7VQ0': 446,
#  'A1GRYVGIXRPT01': 447,
#  'A2GVKIOYWJUT3V': 448,
#  'A1X3P45IMMK0YP': 449,
#  'A2TXGHXIGAT0OX': 450,
#  'A1QMLXUIYVZX8K': 451,
#  'A33G8NK0U6FNX1': 452,
#  'A3LAUV5V97WLVJ': 453,
#  'A2Z0UNA71TZ179': 454,
#  'A2MHOBJU9RME1F': 455,
#  'A2PBZ23XKK4E2Q': 456,
#  'A2B33DNQVGZV9M': 457,
#  'A32VEWQ4STAX3W': 458,
#  'A1MMNZHW3LT0AH': 459,
#  'A2FT44H4K84N5U': 460,
#  'AL4ZYR9NGIXQQ': 461,
#  'AG4056VJW13PI': 462,
#  'A3KJGIQPT106B1': 463,
#  'A2H1U4E1KX4PJH': 464,
#  'A3E05NCMJ1UXD': 465,
#  'A3RVIXD86WUT1E': 466,
#  'A240JZ6KXI3BD8': 467,
#  'A34N5CRKVX8I87': 468,
#  'A1TKXIEZC7YV8K': 469,
#  'A114BWPNZ8EK76': 470,
#  'A3BV07QOSR6065': 471,
#  'A1GCYOMUXYHIGX': 472,
#  'A1WCFCFQL9VWTJ': 473,
#  'A34RVLXUI3DGB': 474,
#  'A2A0WY5WLZLQXZ': 475,
#  'A3Z9TI1OFMD66': 476,
#  'AAYCX7C2HNVHM': 477,
#  'ADUOSJ8X9P0N8': 478,
#  'AX8P5P3ZBWY11': 479,
#  'AQLU2PFZT2Z8H': 480,
#  'A2ZXL50JRVRARV': 481,
#  'A1HOZM1WIV2QPR': 482,
#  'A16ZZUPH1WY8YB': 483,
#  'A25IJ990GR2W8J': 484,
#  'A71U7X56KSSU0': 485,
#  'A3M7LGVQGWQJZI': 486,
#  'A2KADA1V5L2XMI': 487,
#  'A12DMI5HU0GERX': 488,
#  'A8IHSKG11BYII': 489,
#  'A17PP10CTT7THT': 490,
#  'A235657S6LQ432': 491,
#  'A1BJCYTCCC4Y1S': 492,
#  'A3APOBAAWSH6D': 493,
#  'A1WEA8918D31WM': 494,
#  'AYR4NSN9LR2ZX': 495,
#  'AXOH2C12QIT0D': 496,
#  'A33V97QLCA3EZA': 497,
#  'A9NK2TE1849X9': 498,
#  'A1IY3GEVX8XG7U': 499,
#  'A2706QWOWWIXYK': 500,
#  'A1FXITNWC0UQUU': 501,
#  'A1REALDRA0XHV': 502,
#  'A1RDHIL75E5OU4': 503,
#  'A1J9SJ17T9LQHQ': 504,
#  'A3MKFQ7DZFL0YQ': 505,
#  'A20N179UC5I4W8': 506,
#  'A3SPDTC67AOVC': 507,
#  'A21HG2QO3Z5TO6': 508,
#  'A3SX87SXAXJ51N': 509,
#  'A2OG3TK4J0GBYK': 510,
#  'A2BNUZZUTAMHUB': 511,
#  'A30O42O9XUDGNV': 512,
#  'A1U9ILK4ZGBKDP': 513,
#  'A2KI4V6Y0KZF4D': 514,
#  'A3OOLQ7FQOK5A1': 515,
#  'A2WYLNGALT6OW9': 516,
#  'A164TZ11Q9QK6A': 517,
#  'A2N2MYRLFB11HD': 518,
#  'AHBF1APNVCQ1U': 519,
#  'A3HQXWF93Z141C': 520,
#  'A12NS22S16XR0U': 521,
#  'A1PB9WK1GKND9G': 522,
#  'AL2ARRQI0ABFB': 523,
#  'A2P88AUQZNIWZH': 524,
#  'A982P97G5GCFM': 525,
#  'A228BYYYDPIKUY': 526,
#  'A3475QYRA6QLFB': 527,
#  'AYB4ME374XRPS': 528,
#  'ARWL0YSY49PXQ': 529,
#  'APV5YZZMRAJKT': 530,
#  'A4DSB01AREUI3': 531,
#  'A1H5556MWR9Q49': 532,
#  'A3ITWAXL7TLOM': 533,
#  'A3U8BUA18ANNYP': 534,
#  'A11N5AK90MV18J': 535,
#  'A7XEQIMYNGZC0': 536,
#  'A1RP4E3EUSPQG': 537,
#  'A1XSXKCDB0VDLW': 538,
#  'A3UQGGA766ZIS8': 539,
#  'A2CUT3CM3IPFFW': 540,
#  'A3JKGKBXPIF54L': 541,
#  'A3LRF9R3A7X94M': 542,
#  'AVTDWMKYWFXKR': 543,
#  'A2SMTUIA1KWAWH': 544,
#  'A2EA03SLAGW9G6': 545,
#  'A24JRF05T7L766': 546,
#  'A13Y930JWVI5IM': 547,
#  'A2IOTOTOVV96RC': 548,
#  'A1LK51LU6CU5ZZ': 549,
#  'AD2XI9BCPRGGZ': 550,
#  'A19086C0OZ79MG': 551,
#  'A1CLR4MNUPZHDG': 552,
#  'ABPR1HZOOEF1': 553,
#  'A2QL9VLWLALRF8': 554,
#  'A2J9JTVCRDZ2R5': 555,
#  'AFLJAEBX7L0JZ': 556,
#  'A7491OAWX3LPQ': 557,
#  'A2OTY0V1BY93ZT': 558,
#  'A26OZ0CFU00FZI': 559,
#  'A3GFWUSHE6M1KR': 560,
#  'A1R4AZNMLYNX46': 561,
#  'A3J0LOCVOIEDNE': 562,
#  'AK0DI88UVPBLU': 563,
#  'ATQ4Y4URD7V0V': 564,
#  'A2XBK34OND4BZ5': 565,
#  'A1UYWXWO5N25FO': 566,
#  'A19ZBB9630EU3T': 567,
#  'AZ3ZFGQGFGSBB': 568,
#  'A1CJCGZ05IQM3N': 569,
#  'AWBJZ1376R2PQ': 570,
#  'A1Z13ZLQDST84T': 571,
#  'A3QVP4N71A93JT': 572,
#  'AAWACT7O93LD6': 573,
#  'AK7WRADIFNIBV': 574,
#  'A2SZEHVQPFHED1': 575,
#  'A1U2TZMOMGDUB7': 576,
#  'A3Q9LUFNUJZK4E': 577,
#  'A3TI1APBKHERKC': 578,
#  'A15R8EU72EK52L': 579,
#  'A2DDQGBCKU860P': 580,
#  'AKK29FZML547X': 581,
#  'A1LN2TAD9N2LJM': 582,
#  'A107KVRYRCU3RY': 583,
#  'A3ER4DKHHFS6XV': 584,
#  'AMXFS27FYCWEW': 585,
#  'AF1DQ5BDZ9LUL': 586,
#  'A302SU7CUZG70E': 587,
#  'A3N5VZC64QZ55X': 588,
#  'A3N6CTS4TKDWFL': 589,
#  'A3SAZKJS8OHP9B': 590,
#  'AR95LJG9RBSIT': 591,
#  'A18C19EMFOIV0Z': 592,
#  'A2OMF5DYLUWHCS': 593,
#  'A1H76DN5W1GXKA': 594,
#  'A2IZYNQXS2S4WC': 595,
#  'A2KQLBKJ8V7A30': 596,
#  'A1SRAGICWWFYL2': 597,
#  'A10H5MD57IOML3': 598,
#  'A1IR4ILH3LZ754': 599,
#  'AEEULKZLG21F5': 600,
#  'A2J3R1PI7LMW7B': 601,
#  'A38JI8C2TEMA7R': 602,
#  'A7O8RUUQL7USS': 603,
#  'AAXCVMQOGMZNU': 604,
#  'AGR4OX83QTMRC': 605,
#  'A38RPRKD8Z3KT0': 606,
#  'A22UN86W3A7NYD': 607,
#  'A2WVR4R8087WFI': 608,
#  'A3DR3P5SOYVS63': 609,
#  'AB2ETY7XGEW4O': 610,
#  'A3T9AN1LBBJMZB': 611,
#  'A3H8PA7AG48K33': 612,
#  'AYYQF83C109CH': 613,
#  'A8FGB4XK1CKNA': 614,
#  'A322ZVTGN88VR0': 615,
#  'ACPHK59WUG8GI': 616,
#  'A38LZBLSRXU85C': 617,
#  'A2OBZJIWSZD7GG': 618,
#  'AVFZ9IJ9VD7QX': 619,
#  'APYJDUGYJD61P': 620,
#  'A1SG4UH7FWHWZH': 621,
#  'AY0I0RKF8OT33': 622,
#  'A9HAUN793ERO7': 623,
#  'A161BJENWISDKY': 624,
#  'A1CLQWMU7US51I': 625,
#  'A1IWH40X4FRHUJ': 626,
#  'A2NSZCJFNFV9CH': 627,
#  'AD1WVH9MP1ZS6': 628,
#  'A1OJV1DM8ZNGLN': 629,
#  'A3JX3LDBVCRLN4': 630,
#  'A1TAMJYYHBGUW4': 631,
#  'A247Q1CYCJLZED': 632,
#  'ABZPCPU8MSB9D': 633,
#  'AXYU10IGIOVVW': 634,
#  'AIBN43D4T5R5': 635,
#  'A2R7DLFQAIBPUU': 636,
#  'AHGF0X02FNQAH': 637,
#  'ALTTC38P3RJM0': 638,
#  'A2IUO106PDHUSS': 639,
#  'A1F11AR94LAGWI': 640,
#  'A2VIKR5008ESU5': 641,
#  'A55311E616OI4': 642,
#  'A2O3MXBSQMHWEK': 643,
#  'A1GQPVKZY0YG4L': 644,
#  'A2X92IAGA1NMRE': 645,
#  'A1V14R8BFSEZDR': 646,
#  'A364ARFJ95UHME': 647,
#  'A28QD9EEN11K4W': 648,
#  'A1OYAUFHHTUU16': 649,
#  'A1VDRO1HINSFBR': 650,
#  'A2MLJIIJYX79T0': 651,
#  'A37N1TH2XN2P3S': 652,
#  'A3M2558SMDVAVU': 653,
#  'A443D89Y5QMK9': 654,
#  'AJZDO3HSMRU1K': 655,
#  'AX4NMHD9HKZBG': 656,
#  'AN9K5RIP9G37I': 657,
#  'A33N1EAEYEO4BP': 658,
#  'A1U273S5IKF9V0': 659,
#  'A2UO14F8TC6H37': 660,
#  'A2WSGZG2N4VKTN': 661,
#  'APBO7X3S225D8': 662,
#  'AUZJQXCBNP4SV': 663,
#  'A38C1FQ5P6SUYX': 664,
#  'AK1A70PO2UFSJ': 665,
#  'AMBS57NBRG49H': 666,
#  'AOIZPRC342YD0': 667,
#  'AXYUD82X08H1R': 668,
#  'A3K7ZQJ6A88T2G': 669,
#  'AEHS7AFG0NF6Y': 670,
#  'A1TTQODV4W56O6': 671,
#  'A2WQM9LPRG7M68': 672,
#  'A2H5CHLFYTLTLH': 673,
#  'A149R9GPBRBY2N': 674,
#  'APJGN83JNDTG0': 675,
#  'A26P267Z092DDW': 676,
#  'ASVPJTYGAPI6F': 677,
#  'A3CADE0447HR2P': 678,
#  'ANXHEOKB5AD2R': 679,
#  'A1NNLIJZIN6U28': 680,
#  'A340161M66E2RY': 681,
#  'A2RG6IST756FWH': 682,
#  'A1TLKYBPP0AWBW': 683,
#  'A2W230YQ15VA2T': 684,
#  'A3UZURODJV24LP': 685,
#  'A33ZGZ40Q7POT': 686,
#  'AUCD7I6Y56625': 687,
#  'A365B5NVWO9E0Y': 688,
#  'A232MTJHKQ4O0A': 689,
#  'A32315STYXJ7J1': 690,
#  'A2ZCDLEQJZDU14': 691,
#  'A1LLEIYVSMEAFW': 692,
#  'A2YGJOMW2MXC43': 693,
#  'A177AXZOSMEFQA': 694,
#  'A1PABQQ2J4KRGI': 695,
#  'A2EWE0GMBBUVMJ': 696,
#  'A24J3IKZY86OAQ': 697,
#  'AI6UBVJ1SXJEJ': 698,
#  'A20TEW6S2Y0XS3': 699,
#  'A5I50LF7WC02D': 700,
#  'AD5QHM5ZOT7OY': 701,
#  'A20K1KIWLRKG7J': 702,
#  'A2V2FWZ172GTN8': 703,
#  'A2T5FRVR01OS1I': 704,
#  'A3H3VAYVB62X4C': 705,
#  'A15DBRYOV92KEX': 706,
#  'A25I3L92SFR9X7': 707,
#  'APNLLDMDQ5EP5': 708,
#  'A3KIGHGBJ55A4Z': 709,
#  'A1SW3LLWPY8434': 710,
#  'A2UUG79MRD5RUC': 711,
#  'A2KZ0IWDDZU06G': 712,
#  'A1ACM3BW9JK6FQ': 713,
#  'A23U8UAF3IT42U': 714,
#  'A2VHB6GIH7SXPQ': 715,
#  'A1EYSCSTZ0ZOM1': 716,
#  'A1JU10SQPTDABM': 717,
#  'A2CBGM6LYZXXRF': 718,
#  'A382D6Z7VN881Q': 719,
#  'A1UMTPZV9EQYYK': 720,
#  'A3E7NVAJMEYMI7': 721,
#  'ACV2QOBZ4Y00W': 722,
#  'A2GUJF9SHNTK5K': 723,
#  'A2F41VRS8CZUDA': 724,
#  'A1BV7HK6INQ0F7': 725,
#  'A7207N2B9D51O': 726,
#  'A3SAY7Z308OQD3': 727,
#  'A3JU3GG0QXT8B': 728,
#  'ANH84JXTTDNWD': 729,
#  'A2YQSP837GA996': 730,
#  'AW50FUDN8C8OH': 731,
#  'A2U8W57C15G243': 732,
#  'A273TZ7STSVS31': 733,
#  'AS3HRBJ0P6SYM': 734,
#  'A2DLRGLUGVPRRZ': 735,
#  'A3UQQFUW1O2SUJ': 736,
#  'AMHDTZFPD76OS': 737,
#  'A1DKPU24J6ZKS5': 738,
#  'AHDG5QLRNPZAY': 739,
#  'A1XXSNBZPMF9YP': 740,
#  'A25Z01H6HYFGUT': 741,
#  'A3E0XWFOEPORH4': 742,
#  'AB9FSBJIDK4EP': 743,
#  'A2JUPHHT75N0OO': 744,
#  'A3DMDNJ8NRI00I': 745,
#  'A1R5ATA2QG97Z6': 746,
#  'A3HNX23K7E6YH': 747,
#  'A34ZSLK2J23VTE': 748,
#  'A3O7LVFESZEMH7': 749,
#  'A2P371ZIDVORFX': 750,
#  'A10HKS3LFIO8V4': 751,
#  'A39NQ004Z9KZJD': 752,
#  'A1ANC5NLVQWUQM': 753,
#  'A1NY3T0JQV4QNH': 754,
#  'A6I4WK07OGVVT': 755,
#  'A18B06ANIZ9PE8': 756,
#  'A3IXPT6GQG46VI': 757,
#  'A1RC04LUYCE4KJ': 758,
#  'A34NGGEH7MC1KO': 759,
#  'A1ATW46JRJHD5A': 760,
#  'A26O5UDIVR823E': 761,
#  'A2RU5EGR4HZ19D': 762,
#  'A2A2ZJ5CF0ORV7': 763,
#  'A1P5XV7NXT3PO5': 764,
#  'A45GQV1SQ15VH': 765,
#  'A1GXGO15OT1BL0': 766,
#  'A39BD50090WB7R': 767,
#  'A1PLSPQBHVN4M8': 768,
#  'A2O2O78CV1NQHQ': 769,
#  'A2N0MYY8L5YNF4': 770,
#  'AXC2I2983GL1Q': 771,
#  'A2MN6QVOL9PBF0': 772,
#  'AVEKMJ36I5HKW': 773,
#  'AVWIQEW3S4K7Z': 774,
#  'A32CB362TAKUXU': 775,
#  'A38N95PF8HSCD0': 776,
#  'A3QW3DNCPKTSBH': 777,
#  'A3I2OG90QWCQ5Q': 778,
#  'ADD6LAHHFMUIK': 779,
#  'A2NZGC22KNCRNI': 780,
#  'A27DS7YU20QSC4': 781,
#  'A3GKOW37P1WIEA': 782,
#  'A12FGROILOK3L0': 783,
#  'A2W031HYN1S1G9': 784,
#  'A1AFSNYDN7QISN': 785,
#  'A2MADGO60QA509': 786,
#  'APFIB4LHJM1WL': 787,
#  'A69TVXZ62IV3J': 788,
#  'ANTC7YDLFMG3G': 789,
#  'A2028VRTWVLWGI': 790,
#  'A2D3Z9VISO2O02': 791,
#  'A2XAOR1L93PW8': 792,
#  'A2Y0WNETK14R67': 793,
#  'AIAJLEJEAMTVB': 794,
#  'A3PMVC4KBH0EV7': 795,
#  'A92PQT86HZJ6M': 796,
#  'A3815EORT1GBDD': 797,
#  'A1CUY79U0HTI6H': 798,
#  'A2PX66SKRYGBG7': 799,
#  'A2EM4OCOMJ83RY': 800,
#  'A33EIQ8W8F1EHF': 801,
#  'A3PXVTL0NJHHEV': 802,
#  'A38JSYLL6IG5HF': 803,
#  'AQSTSPJP3UBU6': 804,
#  'A3TVME9TY209G7': 805,
#  'A31QMB27GMZIVP': 806,
#  'A1YVH4YXCA9EPY': 807,
#  'A3IQ5AHP61K2H9': 808,
#  'A2AHHKQAG09J41': 809,
#  'A1HFUXSB1EP191': 810,
#  'A1I1SFMMQRDPG9': 811,
#  'A2NXS0EPIIR5NN': 812,
#  'AY5HXKEH7GGF0': 813,
#  'A2J7L11I9NMTF4': 814,
#  'A1DGVM0QJ0JZ15': 815,
#  'A7QJKT25KNJR4': 816,
#  'A3AVCSP6Z426YQ': 817,
#  'A275T1HLI2S6MD': 818,
#  'A33JMFOS4JX6L1': 819,
#  'A1LS4XV7MPBFHT': 820,
#  'A21H25HNKWFBQJ': 821,
#  'A2AM71A1LNP15G': 822,
#  'A1F4K95RMC6GB8': 823,
#  'A1V6KSLF5TFJGY': 824,
#  'AN21GJD355Z5H': 825,
#  'A1ZUSZKNP4SNP4': 826,
#  'A1Z02F8DHEUIDK': 827,
#  'A2VDPG4KA1VIQM': 828,
#  'A17ILR0VCGTPI5': 829,
#  'A27F9FXTQWCFZD': 830,
#  'A2OQO79FTHW4B2': 831,
#  'A1PIRCGV40KDP1': 832,
#  'A1MW8UOVIGS9OP': 833,
#  'A2SZ25F0KPN8ZW': 834,
#  'AESQ6FILAL6ZD': 835,
#  'A3VK65DP34HZY9': 836,
#  'A2MYKL7TSVM9WU': 837,
#  'A1H27CCYS7CNVV': 838,
#  'A13TWJVP5FU2CN': 839,
#  'AR4RP9I5MZR4X': 840,
#  'A1UR6NKGQKKISK': 841,
#  'A21KVHO1N0F9BL': 842,
#  'A3DYVDGGGS1446': 843,
#  'ANR5OD8N9BF07': 844,
#  'A3M3RT2HJ8NVPI': 845,
#  'A1EZ71HK5X7X3I': 846,
#  'ABINME09XJO2X': 847,
#  'ABCV26KZQUMYP': 848,
#  'A6CK7NO7HLZXI': 849,
#  'A5RDQOKJ5EFRF': 850,
#  'A3LOUM0URGC6IE': 851,
#  'A1X8172P74CVV': 852,
#  'AT0O7BGHIC6MN': 853,
#  'A19I7EJ8T7AVIM': 854,
#  'A3NVW35SPP5B8N': 855,
#  'A2ZULERI04J8BY': 856,
#  'A3KRVMR3N8EKQC': 857,
#  'A3AG3ZHG78N4M5': 858,
#  'A1TQUWFDERYG7R': 859,
#  'A3FBKJY0Y8C1R2': 860,
#  'A1TV1KZ2B3M9AZ': 861,
#  'A19ZIRPIWPMM5R': 862,
#  'ACWKO43G7V5W7': 863,
#  'AAZHDUSKG231P': 864,
#  'A1VN0TKPU16FYR': 865,
#  'A2YUC588TSUNK8': 866,
#  'A3BROPOXZSML18': 867,
#  'A3DM8589F32E26': 868,
#  'A2R6M9RUTRXZRN': 869,
#  'A39L8300SXJPKX': 870,
#  'AQ25CCA4527J8': 871,
#  'A3IV4QGWI5P3U9': 872,
#  'A25W3BTFUTQYE0': 873,
#  'AEXU10JSCPELN': 874,
#  'A2NPX3GD0N7FP2': 875,
#  'A2YGBFWXIJ9LVZ': 876,
#  'A318IHVZNNXDV2': 877,
#  'A20NJBWIZ2U5XL': 878,
#  'A2QT4YH3MHKWP': 879,
#  'A17KORFQJEY5U0': 880,
#  'A1Z0RG0VJYEVA7': 881,
#  'A29IE6Z8SFU0NP': 882,
#  'A34O6D0ZPF5O37': 883,
#  'A2KS9HBNFBPZOE': 884,
#  'A35A085ITW77HB': 885,
#  'A3FSLV6WHNFT45': 886,
#  'A2CZ5DG8D5TGYU': 887,
#  'A3VUNVS4B68ZYP': 888,
#  'A1U7SSEL49WFUV': 889,
#  'A1SJYZI5FIM9GV': 890,
#  'A3KMVOPOEI4U6P': 891,
#  'A3NGLZL8GFGZOE': 892,
#  'A348NGK63VTQFG': 893,
#  'A87R87ANLCQ09': 894,
#  'A2UEKUA2PACJ1': 895,
#  'A2ZSTVSMYO3NM5': 896,
#  'A10DPAG6XHKI25': 897,
#  'A3PG2SCWXJEI6L': 898,
#  'A3U6RYJ2O3WY60': 899,
#  'A2PTQ6EVH7ONMD': 900,
#  'A245BMKALC4IFA': 901,
#  'AKIDKKX8CCVRT': 902,
#  'A1WO8WD0PIJ1CV': 903,
#  'A2NOH68U5RSXNT': 904,
#  'A3P99YMJNA5SUA': 905,
#  'A3268URI3NZ05C': 906,
#  'A2MBE3HTZUOKB': 907,
#  'ATCH8Z3J0Q9Y2': 908,
#  'A3ORB910SQINUU': 909,
#  'ADX5B0CXOU42V': 910,
#  'A18STG17U5B05S': 911,
#  'A3EI1TSUV670EJ': 912,
#  'A3UOLEH1EH1RTH': 913,
#  'A2C3AW9U4CVRUI': 914,
#  'A31AMGJM4DGPB8': 915,
#  'A21MQCTRKJKQ2Y': 916,
#  'AEGKCXR0R1ADQ': 917,
#  'A14VM7IZY1IIZA': 918,
#  'AV0B6NGGOAISO': 919,
#  'A2USVKWU57114H': 920,
#  'ACD4R19NL1WXW': 921,
#  'A1A0ILI5N667BT': 922,
#  'A3OY20DR1YO31C': 923,
#  'A10Y0EMEW5LIJS': 924,
#  'A174HG40XAEN8L': 925,
#  'A2IXGQ40W41CMR': 926,
#  'A1O6XVS3FZDWCG': 927,
#  'ABTUJRSFH1YES': 928,
#  'A2L8TXTGGBF6WD': 929,
#  'A3VXWM68MCK266': 930,
#  'A30KJLBL1WAAHK': 931,
#  'A1QWVZVFQPILV5': 932,
#  'A2IUO2BDCPSE5H': 933,
#  'AE2MW0JFZ2O0M': 934,
#  'A1UOFYVCBFODEX': 935,
#  'A371XHOU7P78TV': 936,
#  'A2FU6H29D65USP': 937,
#  'A9DWMULIC9AFY': 938,
#  'AEOZY7BNDIG3E': 939,
#  'A2FG085NB83DRV': 940,
#  'A23FNMCBN5TIUR': 941,
#  'A1PTBXDHR1FX55': 942,
#  'AI3Z8F1OENCTH': 943,
#  'ASD35ZAFZUGHV': 944,
#  'A1UT4KADYSPVZX': 945,
#  'A2YF91W2S5YGQL': 946,
#  'A3P5G2JRA8P06B': 947,
#  'AUZVBSUXJWQ0C': 948,
#  'A3PZ4VZXDFMA4A': 949,
#  'A35N5I05R4RCQI': 950,
#  'A1QRAGXSNRWY02': 951,
#  'A3QVV7UC9S4D8I': 952,
#  'A2FY0VOIF0WLPZ': 953,
#  'A24N10T00RZ5D4': 954,
#  'A2JDLCZ8127MUD': 955,
#  'A15RDHJT75DH9M': 956,
#  'A252MG47ENZ2TK': 957,
#  'A1WLNDIB4KY21P': 958,
#  'A2KGIGJ38ODUT3': 959,
#  'A25D11HLMPONRP': 960,
#  'A2FJMYP1IOPJ9': 961,
#  'A9Z88DDKYF9L3': 962,
#  'A15RA5X8OC5CUM': 963,
#  'A396OG1UFZOO1F': 964,
#  'A3IZNH609L9EAI': 965,
#  'AAO9MM8RYVXZ': 966,
#  'A3L79OS6CW7WUK': 967,
#  'A1BUHUGD4F4SLE': 968,
#  'A3H8M3HWGW8QLJ': 969,
#  'AQ6UVXFGP00CD': 970,
#  'APRE86BCJHRVY': 971,
#  'A2JQJ540SQL126': 972,
#  'AEULHIYYGAGE2': 973,
#  'A4QU03PP6IKZ': 974,
#  'A3O00BUEBIFVAR': 975,
#  'A1DCBETGMBGI3A': 976,
#  'A2JF02X3NQB3OK': 977,
#  'AF1Z09IRUW3KP': 978,
#  'A1ILBKU2J3KGOQ': 979,
#  'A34MH8XE6FGC34': 980,
#  'A215BA6WSZXJLX': 981,
#  'A2HY3JZ423GGEF': 982,
#  'A2WLNJZQ68Y1UN': 983,
#  'A3GXQL9D2E2XIG': 984,
#  'A15UH4JLZLNG1M': 985,
#  'A76CR43A9Q795': 986,
#  'AX64Y4IS5ITIZ': 987,
#  'A38KA0SLAUU9JD': 988,
#  'A348HIBMDBVAGL': 989,
#  'A3Q1TV2UD2NE5U': 990,
#  'A3RI51HPRA793V': 991,
#  'A31WJVZ62109N0': 992,
#  'A3RPHXIIXXRKCA': 993,
#  'A12NKJAUAG2YCR': 994,
#  'A19XT7S4EI4V9B': 995,
#  'A1ZSFPI2T2BIE7': 996,
#  'ASDJKBBV7M8BD': 997,
#  'A3JT0YFAEW3VY6': 998,
#  'A7L6AWDGVCVZG': 999,
#  ...}

# %% [markdown]
# ### Products nodes

# %%
products_query = """
    MATCH (p: Product)
    return  p.asin as asin, p.title as title, p.category as category, p.brand as brand,
            p["fastrp-embedding"] as `fastrp-embedding`,
            p["node2vec-embedding"] as `node2vec-embedding`
"""

products_x, products_mapping = load_node(
    products_query,
    index_col='asin',
    encoders= {
        'category': SequenceEncoder(),
        'fastrp-embedding': IdentityEncoder(is_list=True),
        'node2vec-embedding': IdentityEncoder(is_list=True),
    }
)
# Out:
# items: dict_items([('category', <__main__.SequenceEncoder object at 0x0000027320AE3700>), ('fastrp-embedding', <__main__.IdentityEncoder object at 0x00000273192878B0>), ('node2vec-embedding', <__main__.IdentityEncoder object at 0x0000027320A81900>)])
# Batches:   0%|          | 0/61 [00:00<?, ?it/s]

# %% [markdown]
# ### Ratings edges

# %%
reviews_query = """
    MATCH (u:User)-[r:REVIEWS]-(p:Product)
    return u.id as userId, r.overall as rating, p.asin as asin
"""

edge_index, edge_label = load_edge(
    reviews_query,
    src_index_col='userId',
    src_mapping=user_mapping,
    dst_index_col='asin',
    dst_mapping=products_mapping,
    encoders={
        'rating': IdentityEncoder(dtype=torch.long),
    }
)

# %%
edge_index.shape
# Out:
# torch.Size([2, 71672])

# %% [markdown]
# ### PyG Graph building

# %% [markdown]
# #### Initialize Data

# %%
data = HeteroData()

# users nodes
data['user'].x = user_x

# products nodes
data['product'].x = products_x
data['user', 'reviews', 'product'].edge_index = edge_index
data['user', 'reviews', 'product'].edge_label = edge_label
data.to(device, non_blocking=True)
print(data)
# Out:
# HeteroData(
#   user={ x=[69328, 384] },
#   product={ x=[1941, 640] },
#   (user, reviews, product)={
#     edge_index=[2, 71672],
#     edge_label=[71672]
#   }
# )

# %% [markdown]
# #### Convert them to appropriate format for training a graph-based ML model

# %%
# 1. Add a reverse ('product', 'rev_reviews', 'user') relation for message passing.

# data = T.ToUndirected()(data)
data = ToUndirected()(data)
del data['product', 'rev_reviews', 'user'].edge_label

# 2. Perform a link-level split into training, validation, and test edges.

transform = RandomLinkSplit(
    num_val=0.1,
    num_test=0.1,
    neg_sampling_ratio=0.0,
    edge_types=[('user', 'reviews', 'product')],
    rev_edge_types=[('product', 'rev_reviews', 'user')],
)
train_data, val_data, test_data = transform(data)

# %%
print(train_data)
# Out:
# HeteroData(
#   user={ x=[69328, 384] },
#   product={ x=[1941, 640] },
#   (user, reviews, product)={
#     edge_index=[2, 57338],
#     edge_label=[57338],
#     edge_label_index=[2, 57338]
#   },
#   (product, rev_reviews, user)={ edge_index=[2, 57338] }
# )

# %%
print(test_data)
# Out:
# HeteroData(
#   user={ x=[69328, 384] },
#   product={ x=[1941, 640] },
#   (user, reviews, product)={
#     edge_index=[2, 64505],
#     edge_label=[7167],
#     edge_label_index=[2, 7167]
#   },
#   (product, rev_reviews, user)={ edge_index=[2, 64505] }
# )

# %%
print(val_data)
# Out:
# HeteroData(
#   user={ x=[69328, 384] },
#   product={ x=[1941, 640] },
#   (user, reviews, product)={
#     edge_index=[2, 57338],
#     edge_label=[7167],
#     edge_label_index=[2, 7167]
#   },
#   (product, rev_reviews, user)={ edge_index=[2, 57338] }
# )

# %% [markdown]
# #### Balancing

# %%
torch.bincount(edge_label)
# Out:
# tensor([    0,  5920,  3074,  5112, 11032, 46534])

# %%
# We have an unbalanced dataset with many labels for rating 3 and 4, and very
# few for 0 and 1. Therefore we use a weighted MSE loss.

weight = torch.bincount(train_data['user', 'product'].edge_label)
weight = weight.max() / weight

def weighted_mse_loss(pred, target, weight=None):
    weight = 1. if weight is None else weight[target].to(pred.dtype)
    return (weight * (pred - target.to(pred.dtype)).pow(2)).mean()

# %% [markdown]
# ## Model building

# %%
class GNNEncoder(torch.nn.Module):
    def __init__(self, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = SAGEConv((-1, -1), hidden_channels)
        self.conv2 = SAGEConv((-1, -1), out_channels)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        x = self.conv2(x, edge_index)
        return x
    
class EdgeDecoder(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.lin1 = Linear(2 * hidden_channels, hidden_channels)
        self.lin2 = Linear(hidden_channels, 1)

    def forward(self, z_dict, edge_label_index):
        row, col = edge_label_index
        z = torch.cat([z_dict['user'][row], z_dict['product'][col]], dim=-1)

        z = self.lin1(z).relu()
        z = self.lin2(z)
        return z.view(-1)

class Model(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.encoder = GNNEncoder(hidden_channels, hidden_channels)
        self.encoder = to_hetero(self.encoder, data.metadata(), aggr='sum')
        self.decoder = EdgeDecoder(hidden_channels)

    def forward(self, x_dict, edge_index_dict, edge_label_index):
        z_dict = self.encoder(x_dict, edge_index_dict)
        return self.decoder(z_dict, edge_label_index)

# %%
model = Model(hidden_channels=32).to(device)

# Due to lazy initialization, we need to run one model step so the number
# of parameters can be inferred:
with torch.no_grad():
    model.encoder(train_data.collect('x'), train_data.edge_index_dict)

optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
def train():
    model.train()
    optimizer.zero_grad()
    pred = model(train_data.collect('x'), train_data.edge_index_dict,
                 train_data['user', 'product'].edge_label_index)
    target = train_data['user', 'product'].edge_label
    loss = weighted_mse_loss(pred, target, weight)
    loss.backward()
    optimizer.step()
    return float(loss)

# %%
@torch.no_grad()
def test(data):
    model.eval()
    pred = model(data.collect('x'), data.edge_index_dict,
                 data['user', 'product'].edge_label_index)
    pred = pred.clamp(min=0, max=5)
    target = data['user', 'product'].edge_label.float()
    rmse = F.mse_loss(pred, target).sqrt()
    return float(rmse)

# %%
for epoch in range(1, 301):
    loss = train()
    train_rmse = test(train_data)
    val_rmse = test(val_data)
    test_rmse = test(test_data)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train: {train_rmse:.4f}, '
          f'Val: {val_rmse:.4f}, Test: {test_rmse:.4f}')
# Out:
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[50462,  5157, 20831,  ..., 41157, 15225,  3373],
#         [ 1037,  1456,   461,  ...,   943,  1838,  1422]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 41157, 15225,  3373],
#         [ 1851,   700,  1637,  ...,   943,  1838,  1422]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,   943,  1838,  1422],
#         [15328, 30369, 12649,  ..., 41157, 15225,  3373]])}
# edge_label_index: tensor([[29100, 24200,  6579,  ..., 24450,  1793,  2937],
#         [  646,   574,  1490,  ...,   576,  1380,  1422]])
# neeeeeexxxxtttt.....
# Epoch: 001, Loss: 5.5081, Train: 1.6473, Val: 2.5050, Test: 2.4932
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[50462,  5157, 20831,  ..., 41157, 15225,  3373],
#         [ 1037,  1456,   461,  ...,   943,  1838,  1422]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 41157, 15225,  3373],
#         [ 1851,   700,  1637,  ...,   943,  1838,  1422]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,   943,  1838,  1422],
#         [15328, 30369, 12649,  ..., 41157, 15225,  3373]])}
# edge_label_index: tensor([[29100, 24200,  6579,  ..., 24450,  1793,  2937],
#         [  646,   574,  1490,  ...,   576,  1380,  1422]])
# neeeeeexxxxtttt.....
# Epoch: 002, Loss: 5.5143, Train: 1.5481, Val: 2.4537, Test: 2.4406
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[50462,  5157, 20831,  ..., 41157, 15225,  3373],
#         [ 1037,  1456,   461,  ...,   943,  1838,  1422]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 41157, 15225,  3373],
#         [ 1851,   700,  1637,  ...,   943,  1838,  1422]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,   943,  1838,  1422],
#         [15328, 30369, 12649,  ..., 41157, 15225,  3373]])}
# edge_label_index: tensor([[29100, 24200,  6579,  ..., 24450,  1793,  2937],
#         [  646,   574,  1490,  ...,   576,  1380,  1422]])
# neeeeeexxxxtttt.....
# Epoch: 003, Loss: 5.5269, Train: 1.6963, Val: 2.5272, Test: 2.5160
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[50462,  5157, 20831,  ..., 41157, 15225,  3373],
#         [ 1037,  1456,   461,  ...,   943,  1838,  1422]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 41157, 15225,  3373],
#         [ 1851,   700,  1637,  ...,   943,  1838,  1422]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,   943,  1838,  1422],
#         [15328, 30369, 12649,  ..., 41157, 15225,  3373]])}
# edge_label_index: tensor([[29100, 24200,  6579,  ..., 24450,  1793,  2937],
#         [  646,   574,  1490,  ...,   576,  1380,  1422]])
# neeeeeexxxxtttt.....
# Epoch: 004, Loss: 5.5540, Train: 1.5085, Val: 2.4320, Test: 2.4184
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[50462,  5157, 20831,  ..., 41157, 15225,  3373],
#         [ 1037,  1456,   461,  ...,   943,  1838,  1422]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 41157, 15225,  3373],
#         [ 1851,   700,  1637,  ...,   943,  1838,  1422]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,   943,  1838,  1422],
#         [15328, 30369, 12649,  ..., 41157, 15225,  3373]])}
# edge_label_index: tensor([[29100, 24200,  6579,  ..., 24450,  1793,  2937],
#         [  646,   574,  1490,  ...,   576,  1380,  1422]])
# neeeeeexxxxtttt.....
# Epoch: 005, Loss: 5.5724, Train: 1.7471, Val: 2.5502, Test: 2.5394
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[50462,  5157, 20831,  ..., 41157, 15225,  3373],
#         [ 1037,  1456,   461,  ...,   943,  1838,  1422]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 41157, 15225,  3373],
#         [ 1851,   700,  1637,  ...,   943,  1838,  1422]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,   943,  1838,  1422],
#         [15328, 30369, 12649,  ..., 41157, 15225,  3373]])}
# edge_label_index: tensor([[29100, 24200,  6579,  ..., 24450,  1793,  2937],
#         [  646,   574,  1490,  ...,   576,  1380,  1422]])
# neeeeeexxxxtttt.....
# Epoch: 006, Loss: 5.6256, Train: 1.4836, Val: 2.4169, Test: 2.4026
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[50462,  5157, 20831,  ..., 41157, 15225,  3373],
#         [ 1037,  1456,   461,  ...,   943,  1838,  1422]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 41157, 15225,  3373],
#         [ 1851,   700,  1637,  ...,   943,  1838,  1422]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,   943,  1838,  1422],
#         [15328, 30369, 12649,  ..., 41157, 15225,  3373]])}
# edge_label_index: tensor([[29100, 24200,  6579,  ..., 24450,  1793,  2937],
#         [  646,   574,  1490,  ...,   576,  1380,  1422]])
# neeeeeexxxxtttt.....
# Epoch: 007, Loss: 5.6204, Train: 1.7515, Val: 2.5523, Test: 2.5417
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[50462,  5157, 20831,  ..., 41157, 15225,  3373],
#         [ 1037,  1456,   461,  ...,   943,  1838,  1422]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 41157, 15225,  3373],
#         [ 1851,   700,  1637,  ...,   943,  1838,  1422]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,   943,  1838,  1422],
#         [15328, 30369, 12649,  ..., 41157, 15225,  3373]])}
# edge_label_index: tensor([[29100, 24200,  6579,  ..., 24450,  1793,  2937],
#         [  646,   574,  1490,  ...,   576,  1380,  1422]])
# neeeeeexxxxtttt.....
# Epoch: 008, Loss: 5.6406, Train: 1.5140, Val: 2.4337, Test: 2.4199
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
# ...
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[50462,  5157, 20831,  ..., 41157, 15225,  3373],
#         [ 1037,  1456,   461,  ...,   943,  1838,  1422]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 41157, 15225,  3373],
#         [ 1851,   700,  1637,  ...,   943,  1838,  1422]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,   943,  1838,  1422],
#         [15328, 30369, 12649,  ..., 41157, 15225,  3373]])}
# edge_label_index: tensor([[29100, 24200,  6579,  ..., 24450,  1793,  2937],
#         [  646,   574,  1490,  ...,   576,  1380,  1422]])
# neeeeeexxxxtttt.....
# Epoch: 298, Loss: 5.0815, Train: 1.5586, Val: 2.4916, Test: 2.4763
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[50462,  5157, 20831,  ..., 41157, 15225,  3373],
#         [ 1037,  1456,   461,  ...,   943,  1838,  1422]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 41157, 15225,  3373],
#         [ 1851,   700,  1637,  ...,   943,  1838,  1422]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,   943,  1838,  1422],
#         [15328, 30369, 12649,  ..., 41157, 15225,  3373]])}
# edge_label_index: tensor([[29100, 24200,  6579,  ..., 24450,  1793,  2937],
#         [  646,   574,  1490,  ...,   576,  1380,  1422]])
# neeeeeexxxxtttt.....
# Epoch: 299, Loss: 5.0788, Train: 1.5595, Val: 2.4940, Test: 2.4786
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 18690, 21984, 22101],
#         [ 1851,   700,  1637,  ...,  1594,   254,   366]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,  1594,   254,   366],
#         [15328, 30369, 12649,  ..., 18690, 21984, 22101]])}
# edge_label_index: tensor([[50462,  5157, 20831,  ..., 41157, 15225,  3373],
#         [ 1037,  1456,   461,  ...,   943,  1838,  1422]])
# neeeeeexxxxtttt.....
# x_dict: {'user': tensor([[-0.0863,  0.0119, -0.0082,  ..., -0.0091, -0.0447,  0.0359],
#         [-0.0401, -0.0066, -0.0254,  ...,  0.0582,  0.0009, -0.0501],
#         [-0.0694,  0.0126,  0.0188,  ..., -0.0365,  0.0344, -0.0129],
#         ...,
#         [-0.0399,  0.0636, -0.0150,  ..., -0.0148,  0.0746,  0.0414],
#         [-0.0711,  0.0623, -0.0726,  ..., -0.0267,  0.0121,  0.0176],
#         [-0.0866,  0.0664,  0.0134,  ...,  0.0572,  0.0412, -0.0983]]), 'product': tensor([[-0.0697, -0.0069, -0.0289,  ..., -0.0987,  0.4094, -0.9409],
#         [-0.0697, -0.0069, -0.0289,  ...,  0.0323,  0.7607, -0.3240],
#         [-0.0697, -0.0069, -0.0289,  ..., -0.5236,  0.4073, -0.9528],
#         ...,
#         [-0.0230,  0.0385,  0.0627,  ...,  0.1958, -0.0544, -0.2548],
#         [-0.0230,  0.0385,  0.0627,  ...,  0.3844, -0.0763, -0.1142],
#         [-0.0230,  0.0385,  0.0627,  ..., -0.0090, -0.0380, -0.0968]])}
# edge_index_dict: {('user', 'reviews', 'product'): tensor([[15328, 30369, 12649,  ..., 41157, 15225,  3373],
#         [ 1851,   700,  1637,  ...,   943,  1838,  1422]]), ('product', 'rev_reviews', 'user'): tensor([[ 1851,   700,  1637,  ...,   943,  1838,  1422],
#         [15328, 30369, 12649,  ..., 41157, 15225,  3373]])}
# edge_label_index: tensor([[29100, 24200,  6579,  ..., 24450,  1793,  2937],
#         [  646,   574,  1490,  ...,   576,  1380,  1422]])
# neeeeeexxxxtttt.....
# Epoch: 300, Loss: 5.0760, Train: 1.5598, Val: 2.4955, Test: 2.4801
