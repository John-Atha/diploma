# %%
import matplotlib.pyplot as plt

# %%
def plot(counters):
    plt.bar(counters.keys(), counters.values())

# %% [markdown]
# ### 100K dataset

# %%
counters = {
    0.5: 1096,
    1.0: 3321,
    1.5: 1685,
    2.0: 7258,
    2.5: 4445,
    3.0: 20037,
    3.5: 10509,
    4.0: 28694,
    4.5: 7696,
    5.0: 15048,
}

# %%
plot(counters)

# %% [markdown]
# #### after balancing

# %%
counters = {
    0.5: 1096,
    1.0: 3321,
    1.5: 1685,
    2.0: 7258,
    2.5: 4445,
    3.0: 10037,
    3.5: 10509,
    4.0: 10694,
    4.5: 7696,
    5.0: 11048,
}

# %%
plot(counters)

# %% [markdown]
# ### 1M dataset

# %%
counters = {
    4.5: 159402,
    2.0: 99647,
    2.5: 59193,
    1.0: 48561,
    3.5: 181285,
    4.0: 488530,
    3.0: 321950,
    5.0: 289249,
    1.5: 18831,
    0.5: 20676,
}

# %%
plot(counters)

# %% [markdown]
# ### 25M dataset

# %%
counters = {
    0.5: 32356,
    1.0: 76885,
    1.5: 29790,
    2.0: 157241,
    2.5: 93911,
    3.0: 511357,
    3.5: 285503,
    4.0: 770184,
    4.5: 250008,
    5.0: 453555,
}

# %%
plot(counters)

# %% [markdown]
# #### Balanced dataset with 700K ratings

# %%
counters = {
    0.5: 32356,
    1.0: 76885,
    1.5: 29790,
    2.0: 87241,
    2.5: 93911,
    3.0: 81357,
    3.5: 85503,
    4.0: 95184,
    4.5: 80008,
    5.0: 83555,
}

# %%
plot(counters)

# %% [markdown]
# ### Balanced dataset with 100K ratings

# %%
counters = {
    0.5: 22356,
    1.0: 23885,
    1.5: 24790,
    2.0: 24241,
    2.5: 23911,
    3.0: 21357,
    3.5: 25503,
    4.0: 20184,
    4.5: 20008,
    5.0: 23555,
}

# %%
plot(counters)
