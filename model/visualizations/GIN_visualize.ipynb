# %%
import pathlib
import os
import os.path as osp
import sys
import argparse
parent_path = pathlib.Path(os.getcwd()).parent.absolute()
sys.path.append(str(parent_path))
from utils.visualize import plot_results, plot_loss, plot_test, plot_train, plot_val
from utils.pick_hyperparams import pick_hyperparams
import json

# %% [markdown]
# #### Increasing hidden_channels (till ==128) improves the model

# %%
results_path = "../results/GIN_optimize_2022-11-12 15:30:55.json"
with open(results_path) as f:
    losses = json.load(f)
    plot_loss(losses, ylim=10)

# %%
results_path = "../results/GIN_optimize_2_2022-11-12 16:05:55.json"
with open(results_path) as f:
    losses = json.load(f)
    plot_loss(losses, ylim=10)

# %%
plot_test(losses, ylim=4)
