# %%
import pathlib
import os
import os.path as osp
import sys
import argparse
parent_path = pathlib.Path(os.getcwd()).parent.absolute()
sys.path.append(str(parent_path))
from utils.visualize import plot_results, plot_loss, plot_test, plot_train, plot_val
from utils.pick_hyperparams import pick_hyperparams
import json

# %% [markdown]
# ### GNN types with initial simple configuration

# %% [markdown]
# #### Hidden channels = 8

# %%
results_path = "../results_custom_dataset/GNN_types_8_2022-12-24 16:10:35.json"
with open(results_path) as f:
    losses = json.load(f)
    plot_loss(losses, ylim=10)

# %%
plot_test(losses, ylim=3)

# %% [markdown]
# #### Hidden channels = 16

# %%
results_path = "../results_custom_dataset/GNN_types2_2022-12-24 01:48:14.json"
with open(results_path) as f:
    losses = json.load(f)
    plot_loss(losses, ylim=10)

# %%
plot_test(losses, ylim=5)

# %% [markdown]
# #### Hidden channels = 32

# %%
results_path = "../results_custom_dataset/GNN_types_32_2022-12-24 20:43:06.json"
with open(results_path) as f:
    losses = json.load(f)
    plot_loss(losses, ylim=10)

# %%
plot_test(losses, ylim=5)
