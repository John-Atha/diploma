# %%
import pathlib
import os
import os.path as osp
import sys
import argparse
parent_path = pathlib.Path(os.getcwd()).parent.absolute()
sys.path.append(str(parent_path))
from utils.visualize import plot_results, plot_loss, plot_test, plot_train, plot_val
from utils.pick_hyperparams import pick_hyperparams
import json

# %% [markdown]
# #### SAGE_16 multiple basic aggr combinatios

# %%
results_path = "../results/SAGE_multiple_aggregators2022-11-09 12:46:03.json"
with open(results_path) as f:
    losses = json.load(f)

# %%
plot_loss(losses, ylim=7)

# %%
plot_test(losses, ylim=5)

# %%
pick_hyperparams(results_path)
# Out:
# Loss Type       Best Hyperparams                                                                                                                                                                              Best Value
# --------------  ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  ------------
# Min Loss        ('SAGE', 6, ('max', 'mean'), True, 8, 16, 0.012, ('title', 'tagline', 'overview'), (), ('fastRP_genres', 'fastRP_keywords', 'fastRP_cast', 'fastRP_crew'), ('vote_average', 'vote_count'))       5.25059
# Min Train loss  ('SAGE', 6, ('mean', 'max'), True, 8, 16, 0.012, ('title', 'tagline', 'overview'), (), ('fastRP_genres', 'fastRP_keywords', 'fastRP_cast', 'fastRP_crew'), ('vote_average', 'vote_count'))       1.22777
# ...

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Optimal aggregator:
# * (mean, max) better on evaluations
# * (max, mean) better on training

# %% [markdown]
# ### SAGE 32 multiple basic aggr combinations

# %%
results_path = "../results/SAGE_32_multiple_basic_aggregators2022-11-10 00:16:18.json"
with open(results_path) as f:
    losses = json.load(f)

# %%
plot_loss(losses, ylim=7)

# %%
plot_test(losses)

# %%
pick_hyperparams(results_path)
# Out:
# Loss Type       Best Hyperparams                                                                                                                                                                              Best Value
# --------------  ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  ------------
# Min Loss        ('SAGE', 6, ('max', 'mean'), True, 8, 32, 0.012, ('title', 'tagline', 'overview'), (), ('fastRP_genres', 'fastRP_keywords', 'fastRP_cast', 'fastRP_crew'), ('vote_average', 'vote_count'))       3.49763
# Min Train loss  ('SAGE', 6, ('mean',), True, 8, 32, 0.012, ('title', 'tagline', 'overview'), (), ('fastRP_genres', 'fastRP_keywords', 'fastRP_cast', 'fastRP_crew'), ('vote_average', 'vote_count'))             1.11601
# ...
