# %%
import pathlib
import os
import os.path as osp
import sys
import argparse
parent_path = pathlib.Path(os.getcwd()).parent.absolute()
sys.path.append(str(parent_path))
from utils.visualize import plot_results, plot_loss, plot_test, plot_train, plot_val
from utils.pick_hyperparams import pick_hyperparams
import json

# %% [markdown]
# ## SAGE

# %%
results_path = "../results/SAGE_embeddings_usage2022-12-14 09:15:16.json"
with open(results_path) as f:
    losses = json.load(f)
    plot_loss(losses, ylim=10)

# %%
plot_loss(losses, ylim=6)

# %%
plot_test(losses, ylim=2)
