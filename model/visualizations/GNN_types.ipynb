# %%
import pathlib
import os
import os.path as osp
import sys
import argparse
parent_path = pathlib.Path(os.getcwd()).parent.absolute()
sys.path.append(str(parent_path))
from utils.visualize import plot_results, plot_loss, plot_test, plot_train, plot_val
from utils.pick_hyperparams import pick_hyperparams
import json

# %% [markdown]
# ## 16 hidden_channels full dataset

# %%
results_path = "../results/GNN_types2_2022-11-12 13:46:59.json"
with open(results_path) as f:
    losses = json.load(f)

# %%
plot_loss(losses, ylim=10)

# %%
plot_test(losses, ylim=5)

# %%
pick_hyperparams(results_path)
# Out:
# Loss Type       Best Hyperparams                                                                                                                                                                     Best Value
# --------------  ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  ------------
# Min Loss        ('SAGE', 6, ('mean',), 1, 8, 16, 0.012, ('title', 'tagline', 'overview'), (), ('fastRP_genres', 'fastRP_keywords', 'fastRP_cast', 'fastRP_crew'), ('vote_average', 'vote_count'))       3.85625
# Min Train loss  ('SAGE', 6, ('mean',), 1, 8, 16, 0.012, ('title', 'tagline', 'overview'), (), ('fastRP_genres', 'fastRP_keywords', 'fastRP_cast', 'fastRP_crew'), ('vote_average', 'vote_count'))       1.2195
# ...

# %% [markdown]
# ## 32 hidden_channels full dataset

# %%
results_path = "../results/GNN32_types_2022-11-12 14:07:47.json"
with open(results_path) as f:
    losses = json.load(f)

# %%
plot_loss(losses, ylim=7)

# %%
plot_test(losses, ylim=4)

# %% [markdown]
# ## 64 hidden_channels full dataset

# %%
results_path = "../results/GNN64_types_2022-11-12 14:37:06.json"
with open(results_path) as f:
    losses = json.load(f)

# %%
plot_loss(losses, ylim=7)

# %%
plot_test(losses, ylim=4)

# %%
pick_hyperparams(results_path)
# Out:
# Loss Type       Best Hyperparams                                                                                                                                                                     Best Value
# --------------  ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  ------------
# Min Loss        ('SAGE', 6, ('mean',), 1, 8, 64, 0.012, ('title', 'tagline', 'overview'), (), ('fastRP_genres', 'fastRP_keywords', 'fastRP_cast', 'fastRP_crew'), ('vote_average', 'vote_count'))       3.68842
# Min Train loss  ('SAGE', 6, ('mean',), 1, 8, 64, 0.012, ('title', 'tagline', 'overview'), (), ('fastRP_genres', 'fastRP_keywords', 'fastRP_cast', 'fastRP_crew'), ('vote_average', 'vote_count'))       1.18592
# ...

# %% [markdown]
# ## 32 hidden_channels, dataset without overview

# %%
results_path = "../results/GNN32_types_optimized_dataset_2022-11-12 14:57:16.json"
with open(results_path) as f:
    losses = json.load(f)

# %%
plot_loss(losses, ylim=7)

# %%
plot_test(losses, ylim=4)
