# %%
import pathlib
import os
import os.path as osp
import sys
import argparse
parent_path = pathlib.Path(os.getcwd()).parent.absolute()
sys.path.append(str(parent_path))
from utils.visualize import plot_results, plot_loss, plot_test, plot_train, plot_val
from utils.pick_hyperparams import pick_hyperparams
import json

# %% [markdown]
# ## SAGE 16 WITH MANY DATASET COMBINATIONS

# %%
results_path = "../results/SAGE16_metadata_combinations2022-11-06 18:52:00.json"
with open(results_path) as f:
    losses = json.load(f)

# %%
plot_loss(losses, ylim=7)

# %%
plot_test(losses, ylim=2)

# %%
pick_hyperparams(results_path)
# Out:
# Loss Type       Best Hyperparams                                                     Best Value
# --------------  -----------------------------------------------------------------  ------------
# Min Loss        ('SAGE', 6, True, 8, 16, 0.012, ('title', 'tagline'), (), (), ())       2.48067
# Min Train loss  ('SAGE', 6, True, 8, 16, 0.012, ('title', 'tagline'), (), (), ())       1.07004
# Min Val Loss    ('SAGE', 6, True, 8, 16, 0.012, ('title',), (), (), ())                 1.15236
# Min Test Loss   ('SAGE', 6, True, 8, 16, 0.012, ('title', 'tagline'), (), (), ())       1.14035
