# %%
import pathlib
import os
import os.path as osp
import sys
import argparse
parent_path = pathlib.Path(os.getcwd()).parent.absolute()
sys.path.append(str(parent_path))
from utils.visualize import plot_results, plot_loss, plot_test, plot_train, plot_val
from utils.pick_hyperparams import pick_hyperparams
import json

# %% [markdown]
# ### SAGE embeddings with 16 hidden channels

# %%
results_path = "../results_custom_dataset/SAGE_16_embeddings_2022-12-29 00:07:00.json"
with open(results_path) as f:
    losses = json.load(f)
    plot_loss(losses, ylim=10)

# %%
plot_test(losses, ylim=3)

# %% [markdown]
# ### SAGE embeddings with 32 hidden channels
